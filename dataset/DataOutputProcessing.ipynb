# %%
import torch
import pandas as pd
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from tqdm import tqdm
import gc
import time
from torch.utils.data import DataLoader, TensorDataset
from huggingface_hub import login
from openai import OpenAI
from tqdm import tqdm
import re

# %%
login(token="hf_....")     # HUGGINGFACE TOKEN

# %%
# -------------------------------------
# 1. Configuration
# -------------------------------------

# --- Model and Device Setup ---
# MODIFIED: Switched to the open-access Mistral-7B-Instruct model.
model_name = "mistralai/Mistral-7B-Instruct-v0.3"
device = "cuda" if torch.cuda.is_available() else "cpu"

# --- Performance Tuning ---
# You can tune this based on your VRAM. 16 is a good starting point for a 7B model on a 4070.
BATCH_SIZE = 25

# --- File Paths ---
INPUT_CSV = "ai-medical-chatbot.csv"
CHECKPOINT_CSV = "partial_simplified_notes.csv"
FINAL_CSV = "final_simplified_notes.csv"

# %%
# -------------------------------------
# 2. Load Model and Tokenizer (Optimized)
# -------------------------------------

# Configure 4-bit quantization (this remains the same and is essential)
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

print(f"Loading model: {model_name}")
# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
# Forgetting to set a pad_token is a common source of errors.
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# Load the quantized model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=quantization_config,
    device_map="auto",
    torch_dtype=torch.bfloat16,
    attn_implementation="sdpa",
).eval()

# Optional: JIT compile if PyTorch >= 2.0
if hasattr(torch, "compile"):
    print("Compiling model for faster inference...")
    model = torch.compile(model)

print("Model loaded and compiled successfully.")
# Out:
# Loading model: mistralai/Mistral-7B-Instruct-v0.3
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Compiling model for faster inference...
# Model loaded and compiled successfully.

# %%
# -------------------------------------
# 3. Load Dataset
# -------------------------------------
print(f"Loading dataset from {INPUT_CSV}...")
df = pd.read_csv(INPUT_CSV).dropna(subset=["Description", "Doctor"])
print(f"Loaded {len(df)} records to process.")

# Take a random sample of 60,000 rows (without replacement)
SAMPLE_SIZE = 20000
if len(df) > SAMPLE_SIZE:
    df = df.sample(n=SAMPLE_SIZE, random_state=42).reset_index(drop=True)
    print(f"Randomly sampled {SAMPLE_SIZE} rows.")
else:
    print(f"Dataset has fewer than {SAMPLE_SIZE} rows, using full dataset.")
# Out:
# Loading dataset from ai-medical-chatbot.csv...
# Loaded 256916 records to process.
# Randomly sampled 20000 rows.

# %%
# -------------------------------------
# 4. Build Prompts
# -------------------------------------

def build_prompt(description, doctor_text):
    # This system message helps set the context for the model
    system_message = (
        "You are an expert medical communicator rewriting a doctor's response for a patient. "
        "You MUST follow these rules without exception:\n\n"
        "--- MANDATORY RULES ---\n"
        "1.  **SIMPLIFY & EXPLAIN:** Your only goal is to simplify complex medical terms and explain the core information accurately. NEVER use vague, non-clinical phrases (like 'brain vitamins'); instead, describe the treatment's purpose (e.g., 'nutritional support for brain health').\n\n"
        "2.  **SANITIZE MEDICATIONS (CRITICAL SAFETY RULE):** You MUST NOT use specific medication brand names. ALWAYS replace them with general categories like 'a prescribed pain reliever', 'an antibiotic cream', or 'a lactose-free formula'.\n\n"
        "3.  **IGNORE SENSITIVE DATA (CRITICAL PRIVACY RULE):** The original note may contain personal information like names, emails, or phone numbers. Your job is to IGNORE sentences with this information completely. Rewrite the note focusing only on the medical advice, as if the sensitive data was never there.\n\n"
        "4.  **BE DIRECT & PROFESSIONAL:** NEVER include greetings, introductions, closings, or conversational filler ('Don't worry', 'I hope this helps'). Start the explanation immediately.\n\n"
        "5.  **ENSURE COMPLETENESS:** The final output MUST be a complete thought and MUST NOT end in a partial sentence."
    )
    
    # The user message contains the specific task
    user_message = f"""Rewrite the following doctor's note so a patient can understand it. Use the patient's question as context.

**Patient's Question:**
{description}

**Doctor's Original Note:**
{doctor_text}

**Simplified Version for the Patient:**
"""
    # Using the chat template automatically applies the correct [INST] tags
    return tokenizer.apply_chat_template([
        {"role": "user", "content": f"{system_message}\n\n{user_message}"}
    ], tokenize=False)


print("Building all prompts...")
prompts = [build_prompt(row["Description"], row["Doctor"]) for _, row in df.iterrows()]


def clean_note(text: str) -> str:
    import re

    # --- 1. Sanitize Medications with Smart, Non-Repetitive Replacements ---
    medication_map = {
        r'\b(Tramadol|Acetaminophen|Ibuprofen|Paracetamol|Aspirin|Ultracet)\b': 'an over-the-counter pain reliever',
        r'\b(Pantoprazole|Levosulpiride)\b': 'a medication to manage acid reflux',
        r'\b(Fluoxetine|Sertraline)\b': 'a prescribed antidepressant medication',
        r'\bIsomil\b': 'a special lactose-free formula',
    }
    for pattern, replacement in medication_map.items():
        text = re.sub(f'({pattern})(\s*(or|,|and)\s*{pattern})*', replacement, text, flags=re.IGNORECASE)

    # --- 2. Sanitize Any Remaining Unmapped Medications ---
    generic_meds = [r'\bOralcon\b', r'\bKalarchikai\b', r'\bBenadryl\b', r'\bMoxikind\b', r'\bClobazam\b']
    for med in generic_meds:
        text = re.sub(med, 'a prescribed medication', text, flags=re.IGNORECASE)

    # --- 3. Redact PII ---
    text = re.sub(r'\S+@\S+|\bhttp\S+\b', '[contact information redacted]', text, flags=re.IGNORECASE)
    text = re.sub(r'(\b\d{3}[-.\s]?\d{3}[-.\s]?\d{4}\b|\b\d{10,}\b)', '[phone number redacted]', text)
    
    # --- 4. Remove Conversational Filler (Final Expanded List) ---
    removal_patterns = [

        r"please keep me informed.*", r"if you have any questions related to.*",
        r"please do not hesitate to ask.*", r"please reach out if you have any questions.*",
        r"i wish you.*", r"good luck.*", r"i trust this clarifies.*", r"reach out if you require.*",
        r"take care.*", r"please note.*", r"feel free to.*", r"i'm here to help.*",
        r"rest assured.*", r"if you have further questions.*", r"don't hesitate to.*",
        r"best regards.*", r"sincerely.*", r"i hope this.*helps.*", r"please consult.*", r"\bDr\.$"
    ]
    for pattern in removal_patterns:
        text = re.sub(pattern, "", text, flags=re.IGNORECASE)

    # --- 5. Final Cleanup and Repair ---
    text = re.sub(r'\s{2,}', ' ', text).strip()
    text = re.sub(r'\s+\d+\.?\s*$', '', text) # Remove dangling list numbers
    # Clip any incomplete sentences at the very end
    if not text.endswith((".", "!", "?")):
        last_sentence_end = max(text.rfind('. '), text.rfind('! '), text.rfind('? '))
        if last_sentence_end > 0:
            text = text[:last_sentence_end + 1]

    return text
# Out:
# Building all prompts...

# %%
# -------------------------------------
# 5. Inference with ETA + Checkpoints
# -------------------------------------
total_batches = (len(prompts) + BATCH_SIZE - 1) // BATCH_SIZE
outputs = []
start_time = time.time()

print(f"\nStarting inference with batch size: {BATCH_SIZE}")

for i in range(0, len(prompts), BATCH_SIZE):
    batch_prompts = prompts[i:i + BATCH_SIZE]

    inputs = tokenizer(
        batch_prompts,
        return_tensors="pt",
        padding=True,
        truncation=True,
        max_length=768
    ).to(device)

    with torch.no_grad():
        generated_outputs = model.generate(
            **inputs,
            max_new_tokens=220,
            do_sample=True,
            temperature=0.5,
            top_p=0.9,
            repetition_penalty=1.05,
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.eos_token_id # Important for open-ended generation
        )

    # Decode only the newly generated part
    input_lengths = [len(x) for x in inputs.input_ids]
    decoded_batch = [
        tokenizer.decode(generated_outputs[j][input_lengths[j]:], skip_special_tokens=True).strip()
        for j in range(len(batch_prompts))
    ]
    cleaned_batch = [clean_note(t) for t in decoded_batch]
    outputs.extend(cleaned_batch)

    # --- Progress + ETA ---
    batch_num = (i // BATCH_SIZE) + 1
    elapsed = time.time() - start_time
    avg_time_per_batch = elapsed / batch_num
    remaining_batches = total_batches - batch_num
    eta = avg_time_per_batch * remaining_batches
    print(f"[Batch {batch_num}/{total_batches}] "
          f"Elapsed: {elapsed/60:.1f} min | "
          f"ETA: {eta/60:.1f} min | "
          f"Avg. time/batch: {avg_time_per_batch:.2f}s")

    # --- Save partial progress ---
    if batch_num % 100 == 0:
        temp_df = df.iloc[:len(outputs)].copy()
        temp_df["Simplified_Note"] = outputs
        temp_df.to_csv(CHECKPOINT_CSV, index=False)
        print(f"💾 Saved checkpoint with {len(outputs)} rows to {CHECKPOINT_CSV}")

    # Clean up memory
    del inputs, generated_outputs, decoded_batch
    gc.collect()
    torch.cuda.empty_cache()
# Out:
# Starting inference with batch size: 25
# [Batch 1/800] Elapsed: 0.7 min | ETA: 549.6 min | Avg. time/batch: 41.27s
# [Batch 2/800] Elapsed: 1.4 min | ETA: 555.8 min | Avg. time/batch: 41.79s
# [Batch 3/800] Elapsed: 2.1 min | ETA: 546.3 min | Avg. time/batch: 41.13s
# [Batch 4/800] Elapsed: 2.8 min | ETA: 548.3 min | Avg. time/batch: 41.33s
# [Batch 5/800] Elapsed: 3.7 min | ETA: 591.4 min | Avg. time/batch: 44.63s
# [Batch 6/800] Elapsed: 4.3 min | ETA: 575.6 min | Avg. time/batch: 43.50s
# [Batch 7/800] Elapsed: 5.0 min | ETA: 570.2 min | Avg. time/batch: 43.14s
# [Batch 8/800] Elapsed: 5.7 min | ETA: 563.5 min | Avg. time/batch: 42.69s
# [Batch 9/800] Elapsed: 6.3 min | ETA: 557.2 min | Avg. time/batch: 42.26s
# [Batch 10/800] Elapsed: 7.0 min | ETA: 551.3 min | Avg. time/batch: 41.87s
# [Batch 11/800] Elapsed: 7.6 min | ETA: 547.7 min | Avg. time/batch: 41.65s
# [Batch 12/800] Elapsed: 8.3 min | ETA: 544.6 min | Avg. time/batch: 41.47s
# [Batch 13/800] Elapsed: 9.0 min | ETA: 542.0 min | Avg. time/batch: 41.32s
# [Batch 14/800] Elapsed: 9.6 min | ETA: 536.6 min | Avg. time/batch: 40.96s
# [Batch 15/800] Elapsed: 10.2 min | ETA: 534.7 min | Avg. time/batch: 40.87s
# [Batch 16/800] Elapsed: 10.9 min | ETA: 532.9 min | Avg. time/batch: 40.78s
# [Batch 17/800] Elapsed: 11.4 min | ETA: 526.9 min | Avg. time/batch: 40.38s
# [Batch 18/800] Elapsed: 12.1 min | ETA: 525.6 min | Avg. time/batch: 40.33s
# [Batch 19/800] Elapsed: 12.8 min | ETA: 524.2 min | Avg. time/batch: 40.27s
# [Batch 20/800] Elapsed: 13.4 min | ETA: 523.1 min | Avg. time/batch: 40.23s
# [Batch 21/800] Elapsed: 14.1 min | ETA: 521.9 min | Avg. time/batch: 40.20s
# [Batch 22/800] Elapsed: 14.7 min | ETA: 520.8 min | Avg. time/batch: 40.17s
# [Batch 23/800] Elapsed: 15.4 min | ETA: 519.6 min | Avg. time/batch: 40.12s
# [Batch 24/800] Elapsed: 16.0 min | ETA: 518.6 min | Avg. time/batch: 40.09s
# [Batch 25/800] Elapsed: 16.7 min | ETA: 517.2 min | Avg. time/batch: 40.04s
# [Batch 26/800] Elapsed: 17.3 min | ETA: 514.7 min | Avg. time/batch: 39.90s
# [Batch 27/800] Elapsed: 17.9 min | ETA: 513.3 min | Avg. time/batch: 39.85s
# [Batch 28/800] Elapsed: 18.6 min | ETA: 512.5 min | Avg. time/batch: 39.83s
# [Batch 29/800] Elapsed: 19.2 min | ETA: 510.5 min | Avg. time/batch: 39.73s
# [Batch 30/800] Elapsed: 19.8 min | ETA: 508.4 min | Avg. time/batch: 39.62s
# [Batch 31/800] Elapsed: 20.5 min | ETA: 507.5 min | Avg. time/batch: 39.59s
# [Batch 32/800] Elapsed: 21.1 min | ETA: 506.6 min | Avg. time/batch: 39.58s
# [Batch 33/800] Elapsed: 21.8 min | ETA: 505.9 min | Avg. time/batch: 39.58s
# [Batch 34/800] Elapsed: 22.4 min | ETA: 505.3 min | Avg. time/batch: 39.58s
# [Batch 35/800] Elapsed: 23.1 min | ETA: 504.5 min | Avg. time/batch: 39.57s
# [Batch 36/800] Elapsed: 23.7 min | ETA: 503.4 min | Avg. time/batch: 39.53s
# [Batch 37/800] Elapsed: 24.4 min | ETA: 502.7 min | Avg. time/batch: 39.53s
# [Batch 38/800] Elapsed: 25.0 min | ETA: 501.8 min | Avg. time/batch: 39.51s
# [Batch 39/800] Elapsed: 25.6 min | ETA: 499.4 min | Avg. time/batch: 39.37s
# [Batch 40/800] Elapsed: 26.3 min | ETA: 498.8 min | Avg. time/batch: 39.38s
# [Batch 41/800] Elapsed: 26.9 min | ETA: 497.9 min | Avg. time/batch: 39.36s
# [Batch 42/800] Elapsed: 27.5 min | ETA: 497.1 min | Avg. time/batch: 39.35s
# [Batch 43/800] Elapsed: 28.2 min | ETA: 496.1 min | Avg. time/batch: 39.32s
# [Batch 44/800] Elapsed: 28.8 min | ETA: 494.8 min | Avg. time/batch: 39.27s
# [Batch 45/800] Elapsed: 29.4 min | ETA: 493.7 min | Avg. time/batch: 39.23s
# [Batch 46/800] Elapsed: 30.1 min | ETA: 493.1 min | Avg. time/batch: 39.24s
# [Batch 47/800] Elapsed: 30.7 min | ETA: 492.4 min | Avg. time/batch: 39.24s
# [Batch 48/800] Elapsed: 31.4 min | ETA: 491.8 min | Avg. time/batch: 39.24s
# [Batch 49/800] Elapsed: 32.1 min | ETA: 491.2 min | Avg. time/batch: 39.25s
# [Batch 50/800] Elapsed: 32.7 min | ETA: 490.0 min | Avg. time/batch: 39.20s
# [Batch 51/800] Elapsed: 33.3 min | ETA: 489.5 min | Avg. time/batch: 39.21s
# [Batch 52/800] Elapsed: 34.0 min | ETA: 488.4 min | Avg. time/batch: 39.18s
# [Batch 53/800] Elapsed: 34.6 min | ETA: 487.9 min | Avg. time/batch: 39.19s
# [Batch 54/800] Elapsed: 35.2 min | ETA: 486.7 min | Avg. time/batch: 39.14s
# [Batch 55/800] Elapsed: 35.9 min | ETA: 485.6 min | Avg. time/batch: 39.11s
# [Batch 56/800] Elapsed: 36.5 min | ETA: 485.1 min | Avg. time/batch: 39.12s
# [Batch 57/800] Elapsed: 37.2 min | ETA: 484.4 min | Avg. time/batch: 39.12s
# [Batch 58/800] Elapsed: 37.8 min | ETA: 483.8 min | Avg. time/batch: 39.12s
# [Batch 59/800] Elapsed: 38.5 min | ETA: 483.2 min | Avg. time/batch: 39.13s
# [Batch 60/800] Elapsed: 39.1 min | ETA: 482.1 min | Avg. time/batch: 39.09s
# [Batch 61/800] Elapsed: 39.7 min | ETA: 481.4 min | Avg. time/batch: 39.08s
# [Batch 62/800] Elapsed: 40.3 min | ETA: 479.8 min | Avg. time/batch: 39.01s
# [Batch 63/800] Elapsed: 41.0 min | ETA: 479.3 min | Avg. time/batch: 39.02s
# [Batch 64/800] Elapsed: 41.6 min | ETA: 478.3 min | Avg. time/batch: 38.99s
# [Batch 65/800] Elapsed: 42.2 min | ETA: 477.1 min | Avg. time/batch: 38.94s
# [Batch 66/800] Elapsed: 42.8 min | ETA: 476.5 min | Avg. time/batch: 38.95s
# [Batch 67/800] Elapsed: 43.5 min | ETA: 475.8 min | Avg. time/batch: 38.95s
# [Batch 68/800] Elapsed: 44.1 min | ETA: 474.9 min | Avg. time/batch: 38.93s
# [Batch 69/800] Elapsed: 44.8 min | ETA: 474.3 min | Avg. time/batch: 38.93s
# [Batch 70/800] Elapsed: 45.4 min | ETA: 473.8 min | Avg. time/batch: 38.94s
# [Batch 71/800] Elapsed: 46.1 min | ETA: 473.0 min | Avg. time/batch: 38.93s
# [Batch 72/800] Elapsed: 46.7 min | ETA: 472.4 min | Avg. time/batch: 38.93s
# [Batch 73/800] Elapsed: 47.4 min | ETA: 471.6 min | Avg. time/batch: 38.92s
# [Batch 74/800] Elapsed: 48.0 min | ETA: 471.1 min | Avg. time/batch: 38.93s
# [Batch 75/800] Elapsed: 48.6 min | ETA: 469.5 min | Avg. time/batch: 38.86s
# [Batch 76/800] Elapsed: 49.2 min | ETA: 469.0 min | Avg. time/batch: 38.87s
# [Batch 77/800] Elapsed: 49.9 min | ETA: 468.4 min | Avg. time/batch: 38.87s
# [Batch 78/800] Elapsed: 50.5 min | ETA: 467.9 min | Avg. time/batch: 38.88s
# [Batch 79/800] Elapsed: 51.2 min | ETA: 467.3 min | Avg. time/batch: 38.89s
# [Batch 80/800] Elapsed: 51.9 min | ETA: 466.7 min | Avg. time/batch: 38.89s
# [Batch 81/800] Elapsed: 52.5 min | ETA: 465.8 min | Avg. time/batch: 38.87s
# [Batch 82/800] Elapsed: 53.1 min | ETA: 465.2 min | Avg. time/batch: 38.88s
# [Batch 83/800] Elapsed: 53.8 min | ETA: 464.6 min | Avg. time/batch: 38.88s
# [Batch 84/800] Elapsed: 54.4 min | ETA: 464.0 min | Avg. time/batch: 38.88s
# [Batch 85/800] Elapsed: 55.1 min | ETA: 463.4 min | Avg. time/batch: 38.89s
# [Batch 86/800] Elapsed: 55.7 min | ETA: 462.8 min | Avg. time/batch: 38.89s
# [Batch 87/800] Elapsed: 56.4 min | ETA: 462.3 min | Avg. time/batch: 38.90s
# [Batch 88/800] Elapsed: 57.1 min | ETA: 461.7 min | Avg. time/batch: 38.91s
# [Batch 89/800] Elapsed: 57.7 min | ETA: 460.7 min | Avg. time/batch: 38.88s
# [Batch 90/800] Elapsed: 58.3 min | ETA: 460.2 min | Avg. time/batch: 38.89s
# [Batch 91/800] Elapsed: 59.0 min | ETA: 459.3 min | Avg. time/batch: 38.87s
# [Batch 92/800] Elapsed: 59.6 min | ETA: 458.7 min | Avg. time/batch: 38.87s
# [Batch 93/800] Elapsed: 60.2 min | ETA: 458.0 min | Avg. time/batch: 38.87s
# [Batch 94/800] Elapsed: 60.9 min | ETA: 457.3 min | Avg. time/batch: 38.86s
# [Batch 95/800] Elapsed: 61.5 min | ETA: 456.3 min | Avg. time/batch: 38.84s
# [Batch 96/800] Elapsed: 62.1 min | ETA: 455.4 min | Avg. time/batch: 38.81s
# [Batch 97/800] Elapsed: 62.8 min | ETA: 454.8 min | Avg. time/batch: 38.82s
# [Batch 98/800] Elapsed: 63.4 min | ETA: 454.2 min | Avg. time/batch: 38.82s
# [Batch 99/800] Elapsed: 64.0 min | ETA: 453.4 min | Avg. time/batch: 38.80s
# [Batch 100/800] Elapsed: 64.7 min | ETA: 452.7 min | Avg. time/batch: 38.80s
# 💾 Saved checkpoint with 2500 rows to partial_simplified_notes.csv
# [Batch 101/800] Elapsed: 65.3 min | ETA: 451.9 min | Avg. time/batch: 38.79s
# [Batch 102/800] Elapsed: 65.9 min | ETA: 451.2 min | Avg. time/batch: 38.78s
# [Batch 103/800] Elapsed: 66.6 min | ETA: 450.5 min | Avg. time/batch: 38.78s
# [Batch 104/800] Elapsed: 67.1 min | ETA: 449.1 min | Avg. time/batch: 38.72s
# [Batch 105/800] Elapsed: 67.8 min | ETA: 448.5 min | Avg. time/batch: 38.72s
# [Batch 106/800] Elapsed: 68.4 min | ETA: 447.9 min | Avg. time/batch: 38.72s
# [Batch 107/800] Elapsed: 69.1 min | ETA: 447.3 min | Avg. time/batch: 38.73s
# [Batch 108/800] Elapsed: 69.7 min | ETA: 446.3 min | Avg. time/batch: 38.70s
# [Batch 109/800] Elapsed: 70.3 min | ETA: 445.4 min | Avg. time/batch: 38.67s
# [Batch 110/800] Elapsed: 70.9 min | ETA: 444.8 min | Avg. time/batch: 38.68s
# [Batch 111/800] Elapsed: 71.6 min | ETA: 444.3 min | Avg. time/batch: 38.69s
# [Batch 112/800] Elapsed: 72.2 min | ETA: 443.7 min | Avg. time/batch: 38.69s
# [Batch 113/800] Elapsed: 72.9 min | ETA: 443.1 min | Avg. time/batch: 38.70s
# [Batch 114/800] Elapsed: 73.5 min | ETA: 442.6 min | Avg. time/batch: 38.71s
# [Batch 115/800] Elapsed: 74.2 min | ETA: 442.0 min | Avg. time/batch: 38.71s
# [Batch 116/800] Elapsed: 74.8 min | ETA: 441.1 min | Avg. time/batch: 38.69s
# [Batch 117/800] Elapsed: 75.4 min | ETA: 440.4 min | Avg. time/batch: 38.69s
# [Batch 118/800] Elapsed: 76.1 min | ETA: 439.8 min | Avg. time/batch: 38.69s
# [Batch 119/800] Elapsed: 76.7 min | ETA: 439.0 min | Avg. time/batch: 38.68s
# [Batch 120/800] Elapsed: 77.4 min | ETA: 438.4 min | Avg. time/batch: 38.68s
# [Batch 121/800] Elapsed: 78.0 min | ETA: 437.6 min | Avg. time/batch: 38.66s
# [Batch 122/800] Elapsed: 78.6 min | ETA: 437.0 min | Avg. time/batch: 38.67s
# [Batch 123/800] Elapsed: 79.3 min | ETA: 436.4 min | Avg. time/batch: 38.68s
# [Batch 124/800] Elapsed: 79.9 min | ETA: 435.8 min | Avg. time/batch: 38.68s
# [Batch 125/800] Elapsed: 80.6 min | ETA: 435.1 min | Avg. time/batch: 38.68s
# [Batch 126/800] Elapsed: 81.2 min | ETA: 434.3 min | Avg. time/batch: 38.66s
# [Batch 127/800] Elapsed: 81.8 min | ETA: 433.7 min | Avg. time/batch: 38.67s
# [Batch 128/800] Elapsed: 82.5 min | ETA: 432.9 min | Avg. time/batch: 38.65s
# [Batch 129/800] Elapsed: 83.1 min | ETA: 432.3 min | Avg. time/batch: 38.66s
# [Batch 130/800] Elapsed: 83.8 min | ETA: 431.7 min | Avg. time/batch: 38.66s
# [Batch 131/800] Elapsed: 84.4 min | ETA: 431.0 min | Avg. time/batch: 38.66s
# [Batch 132/800] Elapsed: 85.1 min | ETA: 430.5 min | Avg. time/batch: 38.66s
# [Batch 133/800] Elapsed: 85.7 min | ETA: 429.8 min | Avg. time/batch: 38.66s
# [Batch 134/800] Elapsed: 86.3 min | ETA: 429.0 min | Avg. time/batch: 38.65s
# [Batch 135/800] Elapsed: 87.0 min | ETA: 428.4 min | Avg. time/batch: 38.66s
# [Batch 136/800] Elapsed: 87.6 min | ETA: 427.9 min | Avg. time/batch: 38.66s
# [Batch 137/800] Elapsed: 88.3 min | ETA: 427.3 min | Avg. time/batch: 38.67s
# [Batch 138/800] Elapsed: 88.9 min | ETA: 426.3 min | Avg. time/batch: 38.64s
# [Batch 139/800] Elapsed: 89.5 min | ETA: 425.7 min | Avg. time/batch: 38.64s
# [Batch 140/800] Elapsed: 90.2 min | ETA: 425.1 min | Avg. time/batch: 38.65s
# [Batch 141/800] Elapsed: 90.7 min | ETA: 423.9 min | Avg. time/batch: 38.59s
# [Batch 142/800] Elapsed: 91.3 min | ETA: 423.3 min | Avg. time/batch: 38.60s
# [Batch 143/800] Elapsed: 92.0 min | ETA: 422.6 min | Avg. time/batch: 38.59s
# [Batch 144/800] Elapsed: 92.6 min | ETA: 422.0 min | Avg. time/batch: 38.60s
# [Batch 145/800] Elapsed: 93.2 min | ETA: 421.2 min | Avg. time/batch: 38.58s
# [Batch 146/800] Elapsed: 93.9 min | ETA: 420.6 min | Avg. time/batch: 38.59s
# [Batch 147/800] Elapsed: 94.6 min | ETA: 420.0 min | Avg. time/batch: 38.59s
# [Batch 148/800] Elapsed: 95.2 min | ETA: 419.4 min | Avg. time/batch: 38.60s
# [Batch 149/800] Elapsed: 95.9 min | ETA: 418.8 min | Avg. time/batch: 38.60s
# [Batch 150/800] Elapsed: 96.5 min | ETA: 418.0 min | Avg. time/batch: 38.59s
# [Batch 151/800] Elapsed: 97.1 min | ETA: 417.4 min | Avg. time/batch: 38.59s
# [Batch 152/800] Elapsed: 97.8 min | ETA: 416.9 min | Avg. time/batch: 38.60s
# [Batch 153/800] Elapsed: 98.4 min | ETA: 416.3 min | Avg. time/batch: 38.60s
# [Batch 154/800] Elapsed: 99.0 min | ETA: 415.4 min | Avg. time/batch: 38.58s
# [Batch 155/800] Elapsed: 99.7 min | ETA: 414.7 min | Avg. time/batch: 38.58s
# [Batch 156/800] Elapsed: 100.3 min | ETA: 414.0 min | Avg. time/batch: 38.57s
# [Batch 157/800] Elapsed: 100.9 min | ETA: 413.4 min | Avg. time/batch: 38.58s
# [Batch 158/800] Elapsed: 101.6 min | ETA: 412.8 min | Avg. time/batch: 38.58s
# [Batch 159/800] Elapsed: 102.2 min | ETA: 412.2 min | Avg. time/batch: 38.58s
# [Batch 160/800] Elapsed: 102.9 min | ETA: 411.6 min | Avg. time/batch: 38.59s
# [Batch 161/800] Elapsed: 103.5 min | ETA: 410.9 min | Avg. time/batch: 38.58s
# [Batch 162/800] Elapsed: 104.2 min | ETA: 410.3 min | Avg. time/batch: 38.58s
# [Batch 163/800] Elapsed: 104.8 min | ETA: 409.7 min | Avg. time/batch: 38.59s
# [Batch 164/800] Elapsed: 105.5 min | ETA: 409.0 min | Avg. time/batch: 38.58s
# [Batch 165/800] Elapsed: 106.1 min | ETA: 408.4 min | Avg. time/batch: 38.59s
# [Batch 166/800] Elapsed: 106.8 min | ETA: 407.7 min | Avg. time/batch: 38.59s
# [Batch 167/800] Elapsed: 107.4 min | ETA: 407.2 min | Avg. time/batch: 38.59s
# [Batch 168/800] Elapsed: 108.1 min | ETA: 406.6 min | Avg. time/batch: 38.60s
# [Batch 169/800] Elapsed: 108.7 min | ETA: 406.0 min | Avg. time/batch: 38.60s
# [Batch 170/800] Elapsed: 109.4 min | ETA: 405.4 min | Avg. time/batch: 38.61s
# [Batch 171/800] Elapsed: 110.0 min | ETA: 404.8 min | Avg. time/batch: 38.61s
# [Batch 172/800] Elapsed: 110.7 min | ETA: 404.2 min | Avg. time/batch: 38.62s
# [Batch 173/800] Elapsed: 111.4 min | ETA: 403.6 min | Avg. time/batch: 38.62s
# [Batch 174/800] Elapsed: 112.0 min | ETA: 402.8 min | Avg. time/batch: 38.61s
# [Batch 175/800] Elapsed: 112.6 min | ETA: 402.1 min | Avg. time/batch: 38.60s
# [Batch 176/800] Elapsed: 113.2 min | ETA: 401.5 min | Avg. time/batch: 38.61s
# [Batch 177/800] Elapsed: 113.8 min | ETA: 400.7 min | Avg. time/batch: 38.59s
# [Batch 178/800] Elapsed: 114.5 min | ETA: 400.0 min | Avg. time/batch: 38.58s
# [Batch 179/800] Elapsed: 115.1 min | ETA: 399.4 min | Avg. time/batch: 38.59s
# [Batch 180/800] Elapsed: 115.7 min | ETA: 398.7 min | Avg. time/batch: 38.58s
# [Batch 181/800] Elapsed: 116.4 min | ETA: 398.1 min | Avg. time/batch: 38.59s
# [Batch 182/800] Elapsed: 117.0 min | ETA: 397.3 min | Avg. time/batch: 38.57s
# [Batch 183/800] Elapsed: 117.7 min | ETA: 396.7 min | Avg. time/batch: 38.58s
# [Batch 184/800] Elapsed: 118.3 min | ETA: 396.0 min | Avg. time/batch: 38.58s
# [Batch 185/800] Elapsed: 118.9 min | ETA: 395.4 min | Avg. time/batch: 38.57s
# [Batch 186/800] Elapsed: 119.5 min | ETA: 394.5 min | Avg. time/batch: 38.56s
# [Batch 187/800] Elapsed: 120.2 min | ETA: 394.0 min | Avg. time/batch: 38.56s
# [Batch 188/800] Elapsed: 120.8 min | ETA: 393.4 min | Avg. time/batch: 38.57s
# [Batch 189/800] Elapsed: 121.5 min | ETA: 392.7 min | Avg. time/batch: 38.57s
# [Batch 190/800] Elapsed: 122.1 min | ETA: 392.0 min | Avg. time/batch: 38.56s
# [Batch 191/800] Elapsed: 122.7 min | ETA: 391.3 min | Avg. time/batch: 38.55s
# [Batch 192/800] Elapsed: 123.3 min | ETA: 390.6 min | Avg. time/batch: 38.55s
# [Batch 193/800] Elapsed: 124.0 min | ETA: 390.0 min | Avg. time/batch: 38.55s
# [Batch 194/800] Elapsed: 124.6 min | ETA: 389.3 min | Avg. time/batch: 38.54s
# [Batch 195/800] Elapsed: 125.3 min | ETA: 388.7 min | Avg. time/batch: 38.55s
# [Batch 196/800] Elapsed: 125.9 min | ETA: 388.1 min | Avg. time/batch: 38.55s
# [Batch 197/800] Elapsed: 126.6 min | ETA: 387.5 min | Avg. time/batch: 38.56s
# [Batch 198/800] Elapsed: 127.2 min | ETA: 386.9 min | Avg. time/batch: 38.56s
# [Batch 199/800] Elapsed: 127.9 min | ETA: 386.2 min | Avg. time/batch: 38.55s
# [Batch 200/800] Elapsed: 128.5 min | ETA: 385.4 min | Avg. time/batch: 38.54s
# 💾 Saved checkpoint with 5000 rows to partial_simplified_notes.csv
# [Batch 201/800] Elapsed: 129.1 min | ETA: 384.8 min | Avg. time/batch: 38.54s
# [Batch 202/800] Elapsed: 129.8 min | ETA: 384.1 min | Avg. time/batch: 38.54s
# [Batch 203/800] Elapsed: 130.4 min | ETA: 383.5 min | Avg. time/batch: 38.55s
# [Batch 204/800] Elapsed: 131.0 min | ETA: 382.8 min | Avg. time/batch: 38.54s
# [Batch 205/800] Elapsed: 131.6 min | ETA: 382.0 min | Avg. time/batch: 38.53s
# [Batch 206/800] Elapsed: 132.3 min | ETA: 381.4 min | Avg. time/batch: 38.52s
# [Batch 207/800] Elapsed: 132.9 min | ETA: 380.8 min | Avg. time/batch: 38.53s
# [Batch 208/800] Elapsed: 133.5 min | ETA: 380.0 min | Avg. time/batch: 38.51s
# [Batch 209/800] Elapsed: 134.1 min | ETA: 379.3 min | Avg. time/batch: 38.50s
# [Batch 210/800] Elapsed: 134.8 min | ETA: 378.7 min | Avg. time/batch: 38.51s
# [Batch 211/800] Elapsed: 135.4 min | ETA: 378.0 min | Avg. time/batch: 38.50s
# [Batch 212/800] Elapsed: 136.0 min | ETA: 377.3 min | Avg. time/batch: 38.50s
# [Batch 213/800] Elapsed: 136.7 min | ETA: 376.7 min | Avg. time/batch: 38.50s
# [Batch 214/800] Elapsed: 137.3 min | ETA: 376.0 min | Avg. time/batch: 38.50s
# [Batch 215/800] Elapsed: 138.0 min | ETA: 375.4 min | Avg. time/batch: 38.50s
# [Batch 216/800] Elapsed: 138.6 min | ETA: 374.8 min | Avg. time/batch: 38.51s
# [Batch 217/800] Elapsed: 139.2 min | ETA: 374.1 min | Avg. time/batch: 38.50s
# [Batch 218/800] Elapsed: 139.9 min | ETA: 373.4 min | Avg. time/batch: 38.50s
# [Batch 219/800] Elapsed: 140.5 min | ETA: 372.8 min | Avg. time/batch: 38.50s
# [Batch 220/800] Elapsed: 141.2 min | ETA: 372.1 min | Avg. time/batch: 38.50s
# [Batch 221/800] Elapsed: 141.8 min | ETA: 371.5 min | Avg. time/batch: 38.50s
# [Batch 222/800] Elapsed: 142.5 min | ETA: 370.9 min | Avg. time/batch: 38.50s
# [Batch 223/800] Elapsed: 143.1 min | ETA: 370.2 min | Avg. time/batch: 38.50s
# [Batch 224/800] Elapsed: 143.7 min | ETA: 369.6 min | Avg. time/batch: 38.50s
# [Batch 225/800] Elapsed: 144.4 min | ETA: 368.9 min | Avg. time/batch: 38.50s
# [Batch 226/800] Elapsed: 145.0 min | ETA: 368.3 min | Avg. time/batch: 38.50s
# [Batch 227/800] Elapsed: 145.7 min | ETA: 367.7 min | Avg. time/batch: 38.50s
# [Batch 228/800] Elapsed: 146.3 min | ETA: 367.0 min | Avg. time/batch: 38.49s
# [Batch 229/800] Elapsed: 146.9 min | ETA: 366.2 min | Avg. time/batch: 38.48s
# [Batch 230/800] Elapsed: 147.5 min | ETA: 365.6 min | Avg. time/batch: 38.48s
# [Batch 231/800] Elapsed: 148.2 min | ETA: 365.0 min | Avg. time/batch: 38.48s
# [Batch 232/800] Elapsed: 148.8 min | ETA: 364.3 min | Avg. time/batch: 38.48s
# [Batch 233/800] Elapsed: 149.5 min | ETA: 363.7 min | Avg. time/batch: 38.49s
# [Batch 234/800] Elapsed: 150.1 min | ETA: 363.0 min | Avg. time/batch: 38.48s
# [Batch 235/800] Elapsed: 150.7 min | ETA: 362.4 min | Avg. time/batch: 38.49s
# [Batch 236/800] Elapsed: 151.4 min | ETA: 361.7 min | Avg. time/batch: 38.48s
# [Batch 237/800] Elapsed: 152.0 min | ETA: 361.0 min | Avg. time/batch: 38.47s
# [Batch 238/800] Elapsed: 152.6 min | ETA: 360.4 min | Avg. time/batch: 38.47s
# [Batch 239/800] Elapsed: 153.3 min | ETA: 359.8 min | Avg. time/batch: 38.48s
# [Batch 240/800] Elapsed: 153.9 min | ETA: 359.2 min | Avg. time/batch: 38.48s
# [Batch 241/800] Elapsed: 154.6 min | ETA: 358.6 min | Avg. time/batch: 38.49s
# [Batch 242/800] Elapsed: 155.2 min | ETA: 358.0 min | Avg. time/batch: 38.49s
# [Batch 243/800] Elapsed: 155.9 min | ETA: 357.4 min | Avg. time/batch: 38.50s
# [Batch 244/800] Elapsed: 156.6 min | ETA: 356.8 min | Avg. time/batch: 38.50s
# [Batch 245/800] Elapsed: 157.2 min | ETA: 356.0 min | Avg. time/batch: 38.49s
# [Batch 246/800] Elapsed: 157.8 min | ETA: 355.4 min | Avg. time/batch: 38.49s
# [Batch 247/800] Elapsed: 158.4 min | ETA: 354.7 min | Avg. time/batch: 38.48s
# [Batch 248/800] Elapsed: 159.1 min | ETA: 354.0 min | Avg. time/batch: 38.48s
# [Batch 249/800] Elapsed: 159.7 min | ETA: 353.4 min | Avg. time/batch: 38.48s
# [Batch 250/800] Elapsed: 160.4 min | ETA: 352.8 min | Avg. time/batch: 38.49s
# [Batch 251/800] Elapsed: 161.0 min | ETA: 352.2 min | Avg. time/batch: 38.49s
# [Batch 252/800] Elapsed: 161.7 min | ETA: 351.6 min | Avg. time/batch: 38.50s
# [Batch 253/800] Elapsed: 162.3 min | ETA: 351.0 min | Avg. time/batch: 38.50s
# [Batch 254/800] Elapsed: 163.0 min | ETA: 350.3 min | Avg. time/batch: 38.50s
# [Batch 255/800] Elapsed: 163.6 min | ETA: 349.7 min | Avg. time/batch: 38.50s
# [Batch 256/800] Elapsed: 164.3 min | ETA: 349.1 min | Avg. time/batch: 38.51s
# [Batch 257/800] Elapsed: 165.0 min | ETA: 348.5 min | Avg. time/batch: 38.51s
# [Batch 258/800] Elapsed: 165.6 min | ETA: 347.8 min | Avg. time/batch: 38.51s
# [Batch 259/800] Elapsed: 166.2 min | ETA: 347.2 min | Avg. time/batch: 38.50s
# [Batch 260/800] Elapsed: 166.9 min | ETA: 346.5 min | Avg. time/batch: 38.50s
# [Batch 261/800] Elapsed: 167.5 min | ETA: 345.9 min | Avg. time/batch: 38.50s
# [Batch 262/800] Elapsed: 168.1 min | ETA: 345.3 min | Avg. time/batch: 38.51s
# [Batch 263/800] Elapsed: 168.8 min | ETA: 344.6 min | Avg. time/batch: 38.51s
# [Batch 264/800] Elapsed: 169.4 min | ETA: 343.8 min | Avg. time/batch: 38.49s
# [Batch 265/800] Elapsed: 170.0 min | ETA: 343.2 min | Avg. time/batch: 38.49s
# [Batch 266/800] Elapsed: 170.6 min | ETA: 342.5 min | Avg. time/batch: 38.49s
# [Batch 267/800] Elapsed: 171.3 min | ETA: 341.9 min | Avg. time/batch: 38.49s
# [Batch 268/800] Elapsed: 171.9 min | ETA: 341.3 min | Avg. time/batch: 38.49s
# [Batch 269/800] Elapsed: 172.6 min | ETA: 340.7 min | Avg. time/batch: 38.49s
# [Batch 270/800] Elapsed: 173.2 min | ETA: 340.1 min | Avg. time/batch: 38.50s
# [Batch 271/800] Elapsed: 173.9 min | ETA: 339.4 min | Avg. time/batch: 38.50s
# [Batch 272/800] Elapsed: 174.5 min | ETA: 338.8 min | Avg. time/batch: 38.50s
# [Batch 273/800] Elapsed: 175.1 min | ETA: 338.1 min | Avg. time/batch: 38.49s
# [Batch 274/800] Elapsed: 175.8 min | ETA: 337.5 min | Avg. time/batch: 38.49s
# [Batch 275/800] Elapsed: 176.4 min | ETA: 336.8 min | Avg. time/batch: 38.50s
# [Batch 276/800] Elapsed: 177.1 min | ETA: 336.2 min | Avg. time/batch: 38.50s
# [Batch 277/800] Elapsed: 177.7 min | ETA: 335.6 min | Avg. time/batch: 38.50s
# [Batch 278/800] Elapsed: 178.3 min | ETA: 334.9 min | Avg. time/batch: 38.49s
# [Batch 279/800] Elapsed: 179.0 min | ETA: 334.2 min | Avg. time/batch: 38.49s
# [Batch 280/800] Elapsed: 179.6 min | ETA: 333.5 min | Avg. time/batch: 38.48s
# [Batch 281/800] Elapsed: 180.2 min | ETA: 332.9 min | Avg. time/batch: 38.48s
# [Batch 282/800] Elapsed: 180.9 min | ETA: 332.2 min | Avg. time/batch: 38.48s
# [Batch 283/800] Elapsed: 181.5 min | ETA: 331.6 min | Avg. time/batch: 38.49s
# [Batch 284/800] Elapsed: 182.2 min | ETA: 331.0 min | Avg. time/batch: 38.49s
# [Batch 285/800] Elapsed: 182.8 min | ETA: 330.4 min | Avg. time/batch: 38.49s
# [Batch 286/800] Elapsed: 183.5 min | ETA: 329.7 min | Avg. time/batch: 38.49s
# [Batch 287/800] Elapsed: 184.1 min | ETA: 329.0 min | Avg. time/batch: 38.48s
# [Batch 288/800] Elapsed: 184.7 min | ETA: 328.4 min | Avg. time/batch: 38.48s
# [Batch 289/800] Elapsed: 185.4 min | ETA: 327.8 min | Avg. time/batch: 38.49s
# [Batch 290/800] Elapsed: 186.0 min | ETA: 327.2 min | Avg. time/batch: 38.49s
# [Batch 291/800] Elapsed: 186.7 min | ETA: 326.5 min | Avg. time/batch: 38.49s
# [Batch 292/800] Elapsed: 187.3 min | ETA: 325.9 min | Avg. time/batch: 38.49s
# [Batch 293/800] Elapsed: 188.0 min | ETA: 325.3 min | Avg. time/batch: 38.50s
# [Batch 294/800] Elapsed: 188.6 min | ETA: 324.6 min | Avg. time/batch: 38.49s
# [Batch 295/800] Elapsed: 189.2 min | ETA: 323.9 min | Avg. time/batch: 38.48s
# [Batch 296/800] Elapsed: 189.9 min | ETA: 323.3 min | Avg. time/batch: 38.48s
# [Batch 297/800] Elapsed: 190.5 min | ETA: 322.6 min | Avg. time/batch: 38.49s
# [Batch 298/800] Elapsed: 191.2 min | ETA: 322.0 min | Avg. time/batch: 38.49s
# [Batch 299/800] Elapsed: 191.8 min | ETA: 321.4 min | Avg. time/batch: 38.49s
# [Batch 300/800] Elapsed: 192.5 min | ETA: 320.8 min | Avg. time/batch: 38.50s
# 💾 Saved checkpoint with 7500 rows to partial_simplified_notes.csv
# [Batch 301/800] Elapsed: 193.1 min | ETA: 320.1 min | Avg. time/batch: 38.49s
# [Batch 302/800] Elapsed: 193.7 min | ETA: 319.5 min | Avg. time/batch: 38.49s
# [Batch 303/800] Elapsed: 194.4 min | ETA: 318.8 min | Avg. time/batch: 38.49s
# [Batch 304/800] Elapsed: 195.0 min | ETA: 318.2 min | Avg. time/batch: 38.50s
# [Batch 305/800] Elapsed: 195.7 min | ETA: 317.6 min | Avg. time/batch: 38.50s
# [Batch 306/800] Elapsed: 196.3 min | ETA: 316.9 min | Avg. time/batch: 38.49s
# [Batch 307/800] Elapsed: 196.9 min | ETA: 316.2 min | Avg. time/batch: 38.49s
# [Batch 308/800] Elapsed: 197.6 min | ETA: 315.6 min | Avg. time/batch: 38.49s
# [Batch 309/800] Elapsed: 198.1 min | ETA: 314.8 min | Avg. time/batch: 38.46s
# [Batch 310/800] Elapsed: 198.7 min | ETA: 314.1 min | Avg. time/batch: 38.47s
# [Batch 311/800] Elapsed: 199.4 min | ETA: 313.5 min | Avg. time/batch: 38.46s
# [Batch 312/800] Elapsed: 200.0 min | ETA: 312.8 min | Avg. time/batch: 38.47s
# [Batch 313/800] Elapsed: 200.6 min | ETA: 312.2 min | Avg. time/batch: 38.46s
# [Batch 314/800] Elapsed: 201.3 min | ETA: 311.5 min | Avg. time/batch: 38.46s
# [Batch 315/800] Elapsed: 201.9 min | ETA: 310.9 min | Avg. time/batch: 38.46s
# [Batch 316/800] Elapsed: 202.5 min | ETA: 310.2 min | Avg. time/batch: 38.46s
# [Batch 317/800] Elapsed: 203.2 min | ETA: 309.6 min | Avg. time/batch: 38.46s
# [Batch 318/800] Elapsed: 203.8 min | ETA: 308.9 min | Avg. time/batch: 38.45s
# [Batch 319/800] Elapsed: 204.4 min | ETA: 308.2 min | Avg. time/batch: 38.44s
# [Batch 320/800] Elapsed: 205.0 min | ETA: 307.5 min | Avg. time/batch: 38.44s
# [Batch 321/800] Elapsed: 205.7 min | ETA: 306.9 min | Avg. time/batch: 38.45s
# [Batch 322/800] Elapsed: 206.3 min | ETA: 306.3 min | Avg. time/batch: 38.45s
# [Batch 323/800] Elapsed: 207.0 min | ETA: 305.6 min | Avg. time/batch: 38.45s
# [Batch 324/800] Elapsed: 207.6 min | ETA: 305.0 min | Avg. time/batch: 38.44s
# [Batch 325/800] Elapsed: 208.2 min | ETA: 304.3 min | Avg. time/batch: 38.44s
# [Batch 326/800] Elapsed: 208.9 min | ETA: 303.7 min | Avg. time/batch: 38.45s
# [Batch 327/800] Elapsed: 209.6 min | ETA: 303.1 min | Avg. time/batch: 38.45s
# [Batch 328/800] Elapsed: 210.2 min | ETA: 302.5 min | Avg. time/batch: 38.45s
# [Batch 329/800] Elapsed: 210.8 min | ETA: 301.8 min | Avg. time/batch: 38.45s
# [Batch 330/800] Elapsed: 211.5 min | ETA: 301.2 min | Avg. time/batch: 38.45s
# [Batch 331/800] Elapsed: 212.1 min | ETA: 300.6 min | Avg. time/batch: 38.45s
# [Batch 332/800] Elapsed: 212.8 min | ETA: 299.9 min | Avg. time/batch: 38.45s
# [Batch 333/800] Elapsed: 213.4 min | ETA: 299.3 min | Avg. time/batch: 38.46s
# [Batch 334/800] Elapsed: 214.1 min | ETA: 298.7 min | Avg. time/batch: 38.46s
# [Batch 335/800] Elapsed: 214.7 min | ETA: 298.1 min | Avg. time/batch: 38.46s
# [Batch 336/800] Elapsed: 215.4 min | ETA: 297.4 min | Avg. time/batch: 38.46s
# [Batch 337/800] Elapsed: 216.0 min | ETA: 296.7 min | Avg. time/batch: 38.45s
# [Batch 338/800] Elapsed: 216.6 min | ETA: 296.0 min | Avg. time/batch: 38.44s
# [Batch 339/800] Elapsed: 217.2 min | ETA: 295.4 min | Avg. time/batch: 38.45s
# [Batch 340/800] Elapsed: 217.9 min | ETA: 294.8 min | Avg. time/batch: 38.45s
# [Batch 341/800] Elapsed: 218.5 min | ETA: 294.1 min | Avg. time/batch: 38.45s
# [Batch 342/800] Elapsed: 219.1 min | ETA: 293.5 min | Avg. time/batch: 38.44s
# [Batch 343/800] Elapsed: 219.6 min | ETA: 292.6 min | Avg. time/batch: 38.42s
# [Batch 344/800] Elapsed: 220.3 min | ETA: 292.0 min | Avg. time/batch: 38.42s
# [Batch 345/800] Elapsed: 221.0 min | ETA: 291.4 min | Avg. time/batch: 38.43s
# [Batch 346/800] Elapsed: 221.6 min | ETA: 290.8 min | Avg. time/batch: 38.43s
# [Batch 347/800] Elapsed: 222.3 min | ETA: 290.2 min | Avg. time/batch: 38.43s
# [Batch 348/800] Elapsed: 222.9 min | ETA: 289.5 min | Avg. time/batch: 38.43s
# [Batch 349/800] Elapsed: 223.5 min | ETA: 288.8 min | Avg. time/batch: 38.43s
# [Batch 350/800] Elapsed: 224.1 min | ETA: 288.2 min | Avg. time/batch: 38.42s
# [Batch 351/800] Elapsed: 224.8 min | ETA: 287.5 min | Avg. time/batch: 38.42s
# [Batch 352/800] Elapsed: 225.4 min | ETA: 286.9 min | Avg. time/batch: 38.43s
# [Batch 353/800] Elapsed: 226.1 min | ETA: 286.3 min | Avg. time/batch: 38.43s
# [Batch 354/800] Elapsed: 226.7 min | ETA: 285.6 min | Avg. time/batch: 38.42s
# [Batch 355/800] Elapsed: 227.3 min | ETA: 285.0 min | Avg. time/batch: 38.43s
# [Batch 356/800] Elapsed: 228.0 min | ETA: 284.4 min | Avg. time/batch: 38.43s
# [Batch 357/800] Elapsed: 228.6 min | ETA: 283.7 min | Avg. time/batch: 38.42s
# [Batch 358/800] Elapsed: 229.3 min | ETA: 283.1 min | Avg. time/batch: 38.43s
# [Batch 359/800] Elapsed: 229.9 min | ETA: 282.5 min | Avg. time/batch: 38.43s
# [Batch 360/800] Elapsed: 230.5 min | ETA: 281.8 min | Avg. time/batch: 38.42s
# [Batch 361/800] Elapsed: 231.2 min | ETA: 281.1 min | Avg. time/batch: 38.43s
# [Batch 362/800] Elapsed: 231.8 min | ETA: 280.5 min | Avg. time/batch: 38.43s
# [Batch 363/800] Elapsed: 232.5 min | ETA: 279.9 min | Avg. time/batch: 38.43s
# [Batch 364/800] Elapsed: 233.1 min | ETA: 279.3 min | Avg. time/batch: 38.43s
# [Batch 365/800] Elapsed: 233.7 min | ETA: 278.6 min | Avg. time/batch: 38.42s
# [Batch 366/800] Elapsed: 234.4 min | ETA: 278.0 min | Avg. time/batch: 38.43s
# [Batch 367/800] Elapsed: 235.0 min | ETA: 277.3 min | Avg. time/batch: 38.42s
# [Batch 368/800] Elapsed: 235.7 min | ETA: 276.7 min | Avg. time/batch: 38.42s
# [Batch 369/800] Elapsed: 236.3 min | ETA: 276.0 min | Avg. time/batch: 38.42s
# [Batch 370/800] Elapsed: 236.9 min | ETA: 275.3 min | Avg. time/batch: 38.42s
# [Batch 371/800] Elapsed: 237.5 min | ETA: 274.6 min | Avg. time/batch: 38.41s
# [Batch 372/800] Elapsed: 238.1 min | ETA: 273.9 min | Avg. time/batch: 38.40s
# [Batch 373/800] Elapsed: 238.8 min | ETA: 273.3 min | Avg. time/batch: 38.41s
# [Batch 374/800] Elapsed: 239.4 min | ETA: 272.7 min | Avg. time/batch: 38.41s
# [Batch 375/800] Elapsed: 240.1 min | ETA: 272.1 min | Avg. time/batch: 38.41s
# [Batch 376/800] Elapsed: 240.7 min | ETA: 271.4 min | Avg. time/batch: 38.40s
# [Batch 377/800] Elapsed: 241.3 min | ETA: 270.8 min | Avg. time/batch: 38.41s
# [Batch 378/800] Elapsed: 242.0 min | ETA: 270.1 min | Avg. time/batch: 38.41s
# [Batch 379/800] Elapsed: 242.6 min | ETA: 269.5 min | Avg. time/batch: 38.40s
# [Batch 380/800] Elapsed: 243.2 min | ETA: 268.8 min | Avg. time/batch: 38.41s
# [Batch 381/800] Elapsed: 243.9 min | ETA: 268.2 min | Avg. time/batch: 38.40s
# [Batch 382/800] Elapsed: 244.5 min | ETA: 267.6 min | Avg. time/batch: 38.40s
# [Batch 383/800] Elapsed: 245.2 min | ETA: 266.9 min | Avg. time/batch: 38.41s
# [Batch 384/800] Elapsed: 245.8 min | ETA: 266.2 min | Avg. time/batch: 38.40s
# [Batch 385/800] Elapsed: 246.4 min | ETA: 265.6 min | Avg. time/batch: 38.40s
# [Batch 386/800] Elapsed: 247.0 min | ETA: 265.0 min | Avg. time/batch: 38.40s
# [Batch 387/800] Elapsed: 247.7 min | ETA: 264.3 min | Avg. time/batch: 38.40s
# [Batch 388/800] Elapsed: 248.3 min | ETA: 263.7 min | Avg. time/batch: 38.40s
# [Batch 389/800] Elapsed: 249.0 min | ETA: 263.1 min | Avg. time/batch: 38.40s
# [Batch 390/800] Elapsed: 249.6 min | ETA: 262.4 min | Avg. time/batch: 38.40s
# [Batch 391/800] Elapsed: 250.2 min | ETA: 261.8 min | Avg. time/batch: 38.40s
# [Batch 392/800] Elapsed: 250.9 min | ETA: 261.1 min | Avg. time/batch: 38.40s
# [Batch 393/800] Elapsed: 251.5 min | ETA: 260.4 min | Avg. time/batch: 38.39s
# [Batch 394/800] Elapsed: 252.1 min | ETA: 259.8 min | Avg. time/batch: 38.40s
# [Batch 395/800] Elapsed: 252.7 min | ETA: 259.1 min | Avg. time/batch: 38.39s
# [Batch 396/800] Elapsed: 253.4 min | ETA: 258.5 min | Avg. time/batch: 38.39s
# [Batch 397/800] Elapsed: 254.1 min | ETA: 257.9 min | Avg. time/batch: 38.40s
# [Batch 398/800] Elapsed: 254.7 min | ETA: 257.3 min | Avg. time/batch: 38.40s
# [Batch 399/800] Elapsed: 255.4 min | ETA: 256.6 min | Avg. time/batch: 38.40s
# [Batch 400/800] Elapsed: 256.0 min | ETA: 256.0 min | Avg. time/batch: 38.40s
# 💾 Saved checkpoint with 10000 rows to partial_simplified_notes.csv
# [Batch 401/800] Elapsed: 256.6 min | ETA: 255.4 min | Avg. time/batch: 38.40s
# [Batch 402/800] Elapsed: 257.3 min | ETA: 254.7 min | Avg. time/batch: 38.40s
# [Batch 403/800] Elapsed: 257.9 min | ETA: 254.1 min | Avg. time/batch: 38.40s
# [Batch 404/800] Elapsed: 258.6 min | ETA: 253.5 min | Avg. time/batch: 38.40s
# [Batch 405/800] Elapsed: 259.2 min | ETA: 252.8 min | Avg. time/batch: 38.40s
# [Batch 406/800] Elapsed: 259.8 min | ETA: 252.2 min | Avg. time/batch: 38.40s
# [Batch 407/800] Elapsed: 260.5 min | ETA: 251.5 min | Avg. time/batch: 38.40s
# [Batch 408/800] Elapsed: 261.1 min | ETA: 250.9 min | Avg. time/batch: 38.40s
# [Batch 409/800] Elapsed: 261.8 min | ETA: 250.3 min | Avg. time/batch: 38.41s
# [Batch 410/800] Elapsed: 262.5 min | ETA: 249.7 min | Avg. time/batch: 38.41s
# [Batch 411/800] Elapsed: 263.1 min | ETA: 249.0 min | Avg. time/batch: 38.41s
# [Batch 412/800] Elapsed: 263.7 min | ETA: 248.4 min | Avg. time/batch: 38.41s
# [Batch 413/800] Elapsed: 264.4 min | ETA: 247.7 min | Avg. time/batch: 38.41s
# [Batch 414/800] Elapsed: 265.0 min | ETA: 247.1 min | Avg. time/batch: 38.41s
# [Batch 415/800] Elapsed: 265.6 min | ETA: 246.4 min | Avg. time/batch: 38.41s
# [Batch 416/800] Elapsed: 266.2 min | ETA: 245.8 min | Avg. time/batch: 38.40s
# [Batch 417/800] Elapsed: 266.8 min | ETA: 245.0 min | Avg. time/batch: 38.39s
# [Batch 418/800] Elapsed: 267.4 min | ETA: 244.4 min | Avg. time/batch: 38.38s
# [Batch 419/800] Elapsed: 268.0 min | ETA: 243.7 min | Avg. time/batch: 38.38s
# [Batch 420/800] Elapsed: 268.7 min | ETA: 243.1 min | Avg. time/batch: 38.39s
# [Batch 421/800] Elapsed: 269.3 min | ETA: 242.4 min | Avg. time/batch: 38.38s
# [Batch 422/800] Elapsed: 269.9 min | ETA: 241.8 min | Avg. time/batch: 38.37s
# [Batch 423/800] Elapsed: 270.6 min | ETA: 241.1 min | Avg. time/batch: 38.38s
# [Batch 424/800] Elapsed: 271.2 min | ETA: 240.5 min | Avg. time/batch: 38.38s
# [Batch 425/800] Elapsed: 271.9 min | ETA: 239.9 min | Avg. time/batch: 38.38s
# [Batch 426/800] Elapsed: 272.5 min | ETA: 239.3 min | Avg. time/batch: 38.38s
# [Batch 427/800] Elapsed: 273.2 min | ETA: 238.6 min | Avg. time/batch: 38.38s
# [Batch 428/800] Elapsed: 273.7 min | ETA: 237.9 min | Avg. time/batch: 38.38s
# [Batch 429/800] Elapsed: 274.4 min | ETA: 237.3 min | Avg. time/batch: 38.37s
# [Batch 430/800] Elapsed: 275.0 min | ETA: 236.7 min | Avg. time/batch: 38.38s
# [Batch 431/800] Elapsed: 275.7 min | ETA: 236.0 min | Avg. time/batch: 38.38s
# [Batch 432/800] Elapsed: 276.3 min | ETA: 235.4 min | Avg. time/batch: 38.38s
# [Batch 433/800] Elapsed: 277.0 min | ETA: 234.8 min | Avg. time/batch: 38.38s
# [Batch 434/800] Elapsed: 277.6 min | ETA: 234.1 min | Avg. time/batch: 38.38s
# [Batch 435/800] Elapsed: 278.2 min | ETA: 233.4 min | Avg. time/batch: 38.37s
# [Batch 436/800] Elapsed: 278.8 min | ETA: 232.8 min | Avg. time/batch: 38.37s
# [Batch 437/800] Elapsed: 279.5 min | ETA: 232.1 min | Avg. time/batch: 38.37s
# [Batch 438/800] Elapsed: 280.0 min | ETA: 231.5 min | Avg. time/batch: 38.36s
# [Batch 439/800] Elapsed: 280.7 min | ETA: 230.8 min | Avg. time/batch: 38.36s
# [Batch 440/800] Elapsed: 281.3 min | ETA: 230.1 min | Avg. time/batch: 38.36s
# [Batch 441/800] Elapsed: 281.9 min | ETA: 229.5 min | Avg. time/batch: 38.35s
# [Batch 442/800] Elapsed: 282.5 min | ETA: 228.8 min | Avg. time/batch: 38.34s
# [Batch 443/800] Elapsed: 283.1 min | ETA: 228.1 min | Avg. time/batch: 38.34s
# [Batch 444/800] Elapsed: 283.7 min | ETA: 227.5 min | Avg. time/batch: 38.34s
# [Batch 445/800] Elapsed: 284.3 min | ETA: 226.8 min | Avg. time/batch: 38.34s
# [Batch 446/800] Elapsed: 285.0 min | ETA: 226.2 min | Avg. time/batch: 38.34s
# [Batch 447/800] Elapsed: 285.6 min | ETA: 225.6 min | Avg. time/batch: 38.34s
# [Batch 448/800] Elapsed: 286.3 min | ETA: 224.9 min | Avg. time/batch: 38.34s
# [Batch 449/800] Elapsed: 286.9 min | ETA: 224.3 min | Avg. time/batch: 38.34s
# [Batch 450/800] Elapsed: 287.6 min | ETA: 223.7 min | Avg. time/batch: 38.35s
# [Batch 451/800] Elapsed: 288.3 min | ETA: 223.1 min | Avg. time/batch: 38.35s
# [Batch 452/800] Elapsed: 288.9 min | ETA: 222.4 min | Avg. time/batch: 38.35s
# [Batch 453/800] Elapsed: 289.5 min | ETA: 221.8 min | Avg. time/batch: 38.35s
# [Batch 454/800] Elapsed: 290.2 min | ETA: 221.2 min | Avg. time/batch: 38.35s
# [Batch 455/800] Elapsed: 290.8 min | ETA: 220.5 min | Avg. time/batch: 38.35s
# [Batch 456/800] Elapsed: 291.5 min | ETA: 219.9 min | Avg. time/batch: 38.35s
# [Batch 457/800] Elapsed: 292.1 min | ETA: 219.2 min | Avg. time/batch: 38.35s
# [Batch 458/800] Elapsed: 292.8 min | ETA: 218.6 min | Avg. time/batch: 38.35s
# [Batch 459/800] Elapsed: 293.4 min | ETA: 218.0 min | Avg. time/batch: 38.36s
# [Batch 460/800] Elapsed: 294.1 min | ETA: 217.4 min | Avg. time/batch: 38.36s
# [Batch 461/800] Elapsed: 294.7 min | ETA: 216.7 min | Avg. time/batch: 38.36s
# [Batch 462/800] Elapsed: 295.4 min | ETA: 216.1 min | Avg. time/batch: 38.36s
# [Batch 463/800] Elapsed: 296.0 min | ETA: 215.5 min | Avg. time/batch: 38.36s
# [Batch 464/800] Elapsed: 296.7 min | ETA: 214.8 min | Avg. time/batch: 38.37s
# [Batch 465/800] Elapsed: 297.4 min | ETA: 214.2 min | Avg. time/batch: 38.37s
# [Batch 466/800] Elapsed: 298.0 min | ETA: 213.6 min | Avg. time/batch: 38.37s
# [Batch 467/800] Elapsed: 298.7 min | ETA: 213.0 min | Avg. time/batch: 38.37s
# [Batch 468/800] Elapsed: 299.3 min | ETA: 212.3 min | Avg. time/batch: 38.37s
# [Batch 469/800] Elapsed: 299.9 min | ETA: 211.7 min | Avg. time/batch: 38.37s
# [Batch 470/800] Elapsed: 300.5 min | ETA: 211.0 min | Avg. time/batch: 38.36s
# [Batch 471/800] Elapsed: 301.2 min | ETA: 210.4 min | Avg. time/batch: 38.37s
# [Batch 472/800] Elapsed: 301.7 min | ETA: 209.7 min | Avg. time/batch: 38.35s
# [Batch 473/800] Elapsed: 302.3 min | ETA: 209.0 min | Avg. time/batch: 38.35s
# [Batch 474/800] Elapsed: 303.0 min | ETA: 208.4 min | Avg. time/batch: 38.35s
# [Batch 475/800] Elapsed: 303.6 min | ETA: 207.7 min | Avg. time/batch: 38.35s
# [Batch 476/800] Elapsed: 304.2 min | ETA: 207.1 min | Avg. time/batch: 38.35s
# [Batch 477/800] Elapsed: 304.9 min | ETA: 206.4 min | Avg. time/batch: 38.35s
# [Batch 478/800] Elapsed: 305.5 min | ETA: 205.8 min | Avg. time/batch: 38.35s
# [Batch 479/800] Elapsed: 306.2 min | ETA: 205.2 min | Avg. time/batch: 38.35s
# [Batch 480/800] Elapsed: 306.8 min | ETA: 204.6 min | Avg. time/batch: 38.35s
# [Batch 481/800] Elapsed: 307.5 min | ETA: 203.9 min | Avg. time/batch: 38.36s
# [Batch 482/800] Elapsed: 308.1 min | ETA: 203.3 min | Avg. time/batch: 38.35s
# [Batch 483/800] Elapsed: 308.6 min | ETA: 202.5 min | Avg. time/batch: 38.33s
# [Batch 484/800] Elapsed: 309.2 min | ETA: 201.9 min | Avg. time/batch: 38.34s
# [Batch 485/800] Elapsed: 309.9 min | ETA: 201.3 min | Avg. time/batch: 38.34s
# [Batch 486/800] Elapsed: 310.5 min | ETA: 200.6 min | Avg. time/batch: 38.34s
# [Batch 487/800] Elapsed: 311.2 min | ETA: 200.0 min | Avg. time/batch: 38.34s
# [Batch 488/800] Elapsed: 311.8 min | ETA: 199.3 min | Avg. time/batch: 38.33s
# [Batch 489/800] Elapsed: 312.4 min | ETA: 198.7 min | Avg. time/batch: 38.33s
# [Batch 490/800] Elapsed: 313.1 min | ETA: 198.1 min | Avg. time/batch: 38.33s
# [Batch 491/800] Elapsed: 313.7 min | ETA: 197.4 min | Avg. time/batch: 38.33s
# [Batch 492/800] Elapsed: 314.3 min | ETA: 196.8 min | Avg. time/batch: 38.33s
# [Batch 493/800] Elapsed: 314.9 min | ETA: 196.1 min | Avg. time/batch: 38.33s
# [Batch 494/800] Elapsed: 315.5 min | ETA: 195.5 min | Avg. time/batch: 38.33s
# [Batch 495/800] Elapsed: 316.2 min | ETA: 194.8 min | Avg. time/batch: 38.33s
# [Batch 496/800] Elapsed: 316.8 min | ETA: 194.2 min | Avg. time/batch: 38.32s
# [Batch 497/800] Elapsed: 317.5 min | ETA: 193.5 min | Avg. time/batch: 38.32s
# [Batch 498/800] Elapsed: 318.1 min | ETA: 192.9 min | Avg. time/batch: 38.33s
# [Batch 499/800] Elapsed: 318.8 min | ETA: 192.3 min | Avg. time/batch: 38.33s
# [Batch 500/800] Elapsed: 319.4 min | ETA: 191.6 min | Avg. time/batch: 38.33s
# 💾 Saved checkpoint with 12500 rows to partial_simplified_notes.csv
# [Batch 501/800] Elapsed: 320.0 min | ETA: 191.0 min | Avg. time/batch: 38.33s
# [Batch 502/800] Elapsed: 320.7 min | ETA: 190.4 min | Avg. time/batch: 38.33s
# [Batch 503/800] Elapsed: 321.4 min | ETA: 189.7 min | Avg. time/batch: 38.33s
# [Batch 504/800] Elapsed: 322.0 min | ETA: 189.1 min | Avg. time/batch: 38.33s
# [Batch 505/800] Elapsed: 322.6 min | ETA: 188.5 min | Avg. time/batch: 38.33s
# [Batch 506/800] Elapsed: 323.2 min | ETA: 187.8 min | Avg. time/batch: 38.33s
# [Batch 507/800] Elapsed: 323.9 min | ETA: 187.2 min | Avg. time/batch: 38.33s
# [Batch 508/800] Elapsed: 324.5 min | ETA: 186.5 min | Avg. time/batch: 38.33s
# [Batch 509/800] Elapsed: 325.2 min | ETA: 185.9 min | Avg. time/batch: 38.33s
# [Batch 510/800] Elapsed: 325.8 min | ETA: 185.3 min | Avg. time/batch: 38.33s
# [Batch 511/800] Elapsed: 326.4 min | ETA: 184.6 min | Avg. time/batch: 38.33s
# [Batch 512/800] Elapsed: 327.0 min | ETA: 184.0 min | Avg. time/batch: 38.32s
# [Batch 513/800] Elapsed: 327.7 min | ETA: 183.3 min | Avg. time/batch: 38.32s
# [Batch 514/800] Elapsed: 328.3 min | ETA: 182.7 min | Avg. time/batch: 38.32s
# [Batch 515/800] Elapsed: 328.9 min | ETA: 182.0 min | Avg. time/batch: 38.32s
# [Batch 516/800] Elapsed: 329.5 min | ETA: 181.4 min | Avg. time/batch: 38.32s
# [Batch 517/800] Elapsed: 330.2 min | ETA: 180.7 min | Avg. time/batch: 38.32s
# [Batch 518/800] Elapsed: 330.8 min | ETA: 180.1 min | Avg. time/batch: 38.32s
# [Batch 519/800] Elapsed: 331.4 min | ETA: 179.4 min | Avg. time/batch: 38.32s
# [Batch 520/800] Elapsed: 332.1 min | ETA: 178.8 min | Avg. time/batch: 38.32s
# [Batch 521/800] Elapsed: 332.7 min | ETA: 178.2 min | Avg. time/batch: 38.32s
# [Batch 522/800] Elapsed: 333.4 min | ETA: 177.5 min | Avg. time/batch: 38.32s
# [Batch 523/800] Elapsed: 334.0 min | ETA: 176.9 min | Avg. time/batch: 38.32s
# [Batch 524/800] Elapsed: 334.6 min | ETA: 176.3 min | Avg. time/batch: 38.32s
# [Batch 525/800] Elapsed: 335.2 min | ETA: 175.6 min | Avg. time/batch: 38.30s
# [Batch 526/800] Elapsed: 335.8 min | ETA: 174.9 min | Avg. time/batch: 38.30s
# [Batch 527/800] Elapsed: 336.5 min | ETA: 174.3 min | Avg. time/batch: 38.31s
# [Batch 528/800] Elapsed: 337.1 min | ETA: 173.7 min | Avg. time/batch: 38.31s
# [Batch 529/800] Elapsed: 337.7 min | ETA: 173.0 min | Avg. time/batch: 38.31s
# [Batch 530/800] Elapsed: 338.4 min | ETA: 172.4 min | Avg. time/batch: 38.31s
# [Batch 531/800] Elapsed: 339.1 min | ETA: 171.8 min | Avg. time/batch: 38.31s
# [Batch 532/800] Elapsed: 339.7 min | ETA: 171.1 min | Avg. time/batch: 38.31s
# [Batch 533/800] Elapsed: 340.4 min | ETA: 170.5 min | Avg. time/batch: 38.32s
# [Batch 534/800] Elapsed: 341.0 min | ETA: 169.8 min | Avg. time/batch: 38.31s
# [Batch 535/800] Elapsed: 341.6 min | ETA: 169.2 min | Avg. time/batch: 38.31s
# [Batch 536/800] Elapsed: 342.3 min | ETA: 168.6 min | Avg. time/batch: 38.31s
# [Batch 537/800] Elapsed: 342.9 min | ETA: 167.9 min | Avg. time/batch: 38.31s
# [Batch 538/800] Elapsed: 343.5 min | ETA: 167.3 min | Avg. time/batch: 38.31s
# [Batch 539/800] Elapsed: 344.1 min | ETA: 166.6 min | Avg. time/batch: 38.31s
# [Batch 540/800] Elapsed: 344.7 min | ETA: 166.0 min | Avg. time/batch: 38.30s
# [Batch 541/800] Elapsed: 345.4 min | ETA: 165.4 min | Avg. time/batch: 38.31s
# [Batch 542/800] Elapsed: 346.0 min | ETA: 164.7 min | Avg. time/batch: 38.31s
# [Batch 543/800] Elapsed: 346.7 min | ETA: 164.1 min | Avg. time/batch: 38.31s
# [Batch 544/800] Elapsed: 347.3 min | ETA: 163.4 min | Avg. time/batch: 38.30s
# [Batch 545/800] Elapsed: 347.9 min | ETA: 162.8 min | Avg. time/batch: 38.30s
# [Batch 546/800] Elapsed: 348.6 min | ETA: 162.2 min | Avg. time/batch: 38.30s
# [Batch 547/800] Elapsed: 349.2 min | ETA: 161.5 min | Avg. time/batch: 38.30s
# [Batch 548/800] Elapsed: 349.8 min | ETA: 160.9 min | Avg. time/batch: 38.30s
# [Batch 549/800] Elapsed: 350.5 min | ETA: 160.2 min | Avg. time/batch: 38.30s
# [Batch 550/800] Elapsed: 351.1 min | ETA: 159.6 min | Avg. time/batch: 38.31s
# [Batch 551/800] Elapsed: 351.8 min | ETA: 159.0 min | Avg. time/batch: 38.31s
# [Batch 552/800] Elapsed: 352.4 min | ETA: 158.3 min | Avg. time/batch: 38.31s
# [Batch 553/800] Elapsed: 353.1 min | ETA: 157.7 min | Avg. time/batch: 38.31s
# [Batch 554/800] Elapsed: 353.7 min | ETA: 157.1 min | Avg. time/batch: 38.31s
# [Batch 555/800] Elapsed: 354.4 min | ETA: 156.4 min | Avg. time/batch: 38.31s
# [Batch 556/800] Elapsed: 355.0 min | ETA: 155.8 min | Avg. time/batch: 38.31s
# [Batch 557/800] Elapsed: 355.6 min | ETA: 155.1 min | Avg. time/batch: 38.31s
# [Batch 558/800] Elapsed: 356.3 min | ETA: 154.5 min | Avg. time/batch: 38.31s
# [Batch 559/800] Elapsed: 356.9 min | ETA: 153.9 min | Avg. time/batch: 38.30s
# [Batch 560/800] Elapsed: 357.5 min | ETA: 153.2 min | Avg. time/batch: 38.30s
# [Batch 561/800] Elapsed: 358.1 min | ETA: 152.6 min | Avg. time/batch: 38.30s
# [Batch 562/800] Elapsed: 358.8 min | ETA: 151.9 min | Avg. time/batch: 38.30s
# [Batch 563/800] Elapsed: 359.4 min | ETA: 151.3 min | Avg. time/batch: 38.31s
# [Batch 564/800] Elapsed: 360.1 min | ETA: 150.7 min | Avg. time/batch: 38.31s
# [Batch 565/800] Elapsed: 360.7 min | ETA: 150.0 min | Avg. time/batch: 38.31s
# [Batch 566/800] Elapsed: 361.3 min | ETA: 149.4 min | Avg. time/batch: 38.30s
# [Batch 567/800] Elapsed: 362.0 min | ETA: 148.8 min | Avg. time/batch: 38.31s
# [Batch 568/800] Elapsed: 362.6 min | ETA: 148.1 min | Avg. time/batch: 38.31s
# [Batch 569/800] Elapsed: 363.3 min | ETA: 147.5 min | Avg. time/batch: 38.31s
# [Batch 570/800] Elapsed: 363.9 min | ETA: 146.8 min | Avg. time/batch: 38.31s
# [Batch 571/800] Elapsed: 364.5 min | ETA: 146.2 min | Avg. time/batch: 38.31s
# [Batch 572/800] Elapsed: 365.2 min | ETA: 145.6 min | Avg. time/batch: 38.31s
# [Batch 573/800] Elapsed: 365.9 min | ETA: 144.9 min | Avg. time/batch: 38.31s
# [Batch 574/800] Elapsed: 366.5 min | ETA: 144.3 min | Avg. time/batch: 38.31s
# [Batch 575/800] Elapsed: 367.2 min | ETA: 143.7 min | Avg. time/batch: 38.31s
# [Batch 576/800] Elapsed: 367.8 min | ETA: 143.0 min | Avg. time/batch: 38.31s
# [Batch 577/800] Elapsed: 368.4 min | ETA: 142.4 min | Avg. time/batch: 38.31s
# [Batch 578/800] Elapsed: 369.0 min | ETA: 141.7 min | Avg. time/batch: 38.31s
# [Batch 579/800] Elapsed: 369.7 min | ETA: 141.1 min | Avg. time/batch: 38.31s
# [Batch 580/800] Elapsed: 370.3 min | ETA: 140.5 min | Avg. time/batch: 38.31s
# [Batch 581/800] Elapsed: 370.9 min | ETA: 139.8 min | Avg. time/batch: 38.31s
# [Batch 582/800] Elapsed: 371.6 min | ETA: 139.2 min | Avg. time/batch: 38.31s
# [Batch 583/800] Elapsed: 372.3 min | ETA: 138.6 min | Avg. time/batch: 38.31s
# [Batch 584/800] Elapsed: 372.9 min | ETA: 137.9 min | Avg. time/batch: 38.31s
# [Batch 585/800] Elapsed: 373.5 min | ETA: 137.3 min | Avg. time/batch: 38.31s
# [Batch 586/800] Elapsed: 374.1 min | ETA: 136.6 min | Avg. time/batch: 38.31s
# [Batch 587/800] Elapsed: 374.8 min | ETA: 136.0 min | Avg. time/batch: 38.31s
# [Batch 588/800] Elapsed: 375.4 min | ETA: 135.4 min | Avg. time/batch: 38.31s
# [Batch 589/800] Elapsed: 376.1 min | ETA: 134.7 min | Avg. time/batch: 38.31s
# [Batch 590/800] Elapsed: 376.7 min | ETA: 134.1 min | Avg. time/batch: 38.31s
# [Batch 591/800] Elapsed: 377.3 min | ETA: 133.4 min | Avg. time/batch: 38.31s
# [Batch 592/800] Elapsed: 378.0 min | ETA: 132.8 min | Avg. time/batch: 38.31s
# [Batch 593/800] Elapsed: 378.6 min | ETA: 132.2 min | Avg. time/batch: 38.31s
# [Batch 594/800] Elapsed: 379.3 min | ETA: 131.5 min | Avg. time/batch: 38.31s
# [Batch 595/800] Elapsed: 379.9 min | ETA: 130.9 min | Avg. time/batch: 38.31s
# [Batch 596/800] Elapsed: 380.6 min | ETA: 130.3 min | Avg. time/batch: 38.31s
# [Batch 597/800] Elapsed: 381.2 min | ETA: 129.6 min | Avg. time/batch: 38.31s
# [Batch 598/800] Elapsed: 381.9 min | ETA: 129.0 min | Avg. time/batch: 38.32s
# [Batch 599/800] Elapsed: 382.5 min | ETA: 128.4 min | Avg. time/batch: 38.32s
# [Batch 600/800] Elapsed: 383.2 min | ETA: 127.7 min | Avg. time/batch: 38.32s
# 💾 Saved checkpoint with 15000 rows to partial_simplified_notes.csv
# [Batch 601/800] Elapsed: 383.8 min | ETA: 127.1 min | Avg. time/batch: 38.32s
# [Batch 602/800] Elapsed: 384.5 min | ETA: 126.5 min | Avg. time/batch: 38.32s
# [Batch 603/800] Elapsed: 385.2 min | ETA: 125.8 min | Avg. time/batch: 38.32s
# [Batch 604/800] Elapsed: 385.8 min | ETA: 125.2 min | Avg. time/batch: 38.33s
# [Batch 605/800] Elapsed: 386.5 min | ETA: 124.6 min | Avg. time/batch: 38.33s
# [Batch 606/800] Elapsed: 387.1 min | ETA: 123.9 min | Avg. time/batch: 38.33s
# [Batch 607/800] Elapsed: 387.7 min | ETA: 123.3 min | Avg. time/batch: 38.32s
# [Batch 608/800] Elapsed: 388.3 min | ETA: 122.6 min | Avg. time/batch: 38.32s
# [Batch 609/800] Elapsed: 389.0 min | ETA: 122.0 min | Avg. time/batch: 38.33s
# [Batch 610/800] Elapsed: 389.7 min | ETA: 121.4 min | Avg. time/batch: 38.33s
# [Batch 611/800] Elapsed: 390.3 min | ETA: 120.7 min | Avg. time/batch: 38.33s
# [Batch 612/800] Elapsed: 391.0 min | ETA: 120.1 min | Avg. time/batch: 38.33s
# [Batch 613/800] Elapsed: 391.6 min | ETA: 119.5 min | Avg. time/batch: 38.33s
# [Batch 614/800] Elapsed: 392.2 min | ETA: 118.8 min | Avg. time/batch: 38.33s
# [Batch 615/800] Elapsed: 392.8 min | ETA: 118.2 min | Avg. time/batch: 38.32s
# [Batch 616/800] Elapsed: 393.5 min | ETA: 117.5 min | Avg. time/batch: 38.33s
# [Batch 617/800] Elapsed: 394.1 min | ETA: 116.9 min | Avg. time/batch: 38.33s
# [Batch 618/800] Elapsed: 394.8 min | ETA: 116.3 min | Avg. time/batch: 38.33s
# [Batch 619/800] Elapsed: 395.3 min | ETA: 115.6 min | Avg. time/batch: 38.32s
# [Batch 620/800] Elapsed: 396.0 min | ETA: 115.0 min | Avg. time/batch: 38.32s
# [Batch 621/800] Elapsed: 396.7 min | ETA: 114.3 min | Avg. time/batch: 38.32s
# [Batch 622/800] Elapsed: 397.3 min | ETA: 113.7 min | Avg. time/batch: 38.33s
# [Batch 623/800] Elapsed: 397.9 min | ETA: 113.1 min | Avg. time/batch: 38.32s
# [Batch 624/800] Elapsed: 398.6 min | ETA: 112.4 min | Avg. time/batch: 38.32s
# [Batch 625/800] Elapsed: 399.2 min | ETA: 111.8 min | Avg. time/batch: 38.32s
# [Batch 626/800] Elapsed: 399.9 min | ETA: 111.1 min | Avg. time/batch: 38.33s
# [Batch 627/800] Elapsed: 400.5 min | ETA: 110.5 min | Avg. time/batch: 38.32s
# [Batch 628/800] Elapsed: 401.1 min | ETA: 109.9 min | Avg. time/batch: 38.32s
# [Batch 629/800] Elapsed: 401.7 min | ETA: 109.2 min | Avg. time/batch: 38.32s
# [Batch 630/800] Elapsed: 402.4 min | ETA: 108.6 min | Avg. time/batch: 38.32s
# [Batch 631/800] Elapsed: 403.0 min | ETA: 107.9 min | Avg. time/batch: 38.32s
# [Batch 632/800] Elapsed: 403.7 min | ETA: 107.3 min | Avg. time/batch: 38.32s
# [Batch 633/800] Elapsed: 404.3 min | ETA: 106.7 min | Avg. time/batch: 38.33s
# [Batch 634/800] Elapsed: 405.0 min | ETA: 106.0 min | Avg. time/batch: 38.33s
# [Batch 635/800] Elapsed: 405.6 min | ETA: 105.4 min | Avg. time/batch: 38.32s
# [Batch 636/800] Elapsed: 406.2 min | ETA: 104.7 min | Avg. time/batch: 38.32s
# [Batch 637/800] Elapsed: 406.9 min | ETA: 104.1 min | Avg. time/batch: 38.32s
# [Batch 638/800] Elapsed: 407.5 min | ETA: 103.5 min | Avg. time/batch: 38.32s
# [Batch 639/800] Elapsed: 408.2 min | ETA: 102.8 min | Avg. time/batch: 38.32s
# [Batch 640/800] Elapsed: 408.8 min | ETA: 102.2 min | Avg. time/batch: 38.32s
# [Batch 641/800] Elapsed: 409.4 min | ETA: 101.6 min | Avg. time/batch: 38.32s
# [Batch 642/800] Elapsed: 410.1 min | ETA: 100.9 min | Avg. time/batch: 38.33s
# [Batch 643/800] Elapsed: 410.7 min | ETA: 100.3 min | Avg. time/batch: 38.33s
# [Batch 644/800] Elapsed: 411.4 min | ETA: 99.7 min | Avg. time/batch: 38.33s
# [Batch 645/800] Elapsed: 412.1 min | ETA: 99.0 min | Avg. time/batch: 38.33s
# [Batch 646/800] Elapsed: 412.7 min | ETA: 98.4 min | Avg. time/batch: 38.33s
# [Batch 647/800] Elapsed: 413.2 min | ETA: 97.7 min | Avg. time/batch: 38.32s
# [Batch 648/800] Elapsed: 413.8 min | ETA: 97.1 min | Avg. time/batch: 38.31s
# [Batch 649/800] Elapsed: 414.4 min | ETA: 96.4 min | Avg. time/batch: 38.31s
# [Batch 650/800] Elapsed: 415.1 min | ETA: 95.8 min | Avg. time/batch: 38.31s
# [Batch 651/800] Elapsed: 415.7 min | ETA: 95.2 min | Avg. time/batch: 38.32s
# [Batch 652/800] Elapsed: 416.4 min | ETA: 94.5 min | Avg. time/batch: 38.32s
# [Batch 653/800] Elapsed: 417.0 min | ETA: 93.9 min | Avg. time/batch: 38.32s
# [Batch 654/800] Elapsed: 417.7 min | ETA: 93.2 min | Avg. time/batch: 38.32s
# [Batch 655/800] Elapsed: 418.3 min | ETA: 92.6 min | Avg. time/batch: 38.32s
# [Batch 656/800] Elapsed: 419.0 min | ETA: 92.0 min | Avg. time/batch: 38.32s
# [Batch 657/800] Elapsed: 419.6 min | ETA: 91.3 min | Avg. time/batch: 38.32s
# [Batch 658/800] Elapsed: 420.2 min | ETA: 90.7 min | Avg. time/batch: 38.32s
# [Batch 659/800] Elapsed: 420.9 min | ETA: 90.0 min | Avg. time/batch: 38.32s
# [Batch 660/800] Elapsed: 421.5 min | ETA: 89.4 min | Avg. time/batch: 38.32s
# [Batch 661/800] Elapsed: 422.2 min | ETA: 88.8 min | Avg. time/batch: 38.32s
# [Batch 662/800] Elapsed: 422.8 min | ETA: 88.1 min | Avg. time/batch: 38.32s
# [Batch 663/800] Elapsed: 423.5 min | ETA: 87.5 min | Avg. time/batch: 38.32s
# [Batch 664/800] Elapsed: 424.1 min | ETA: 86.9 min | Avg. time/batch: 38.32s
# [Batch 665/800] Elapsed: 424.7 min | ETA: 86.2 min | Avg. time/batch: 38.32s
# [Batch 666/800] Elapsed: 425.4 min | ETA: 85.6 min | Avg. time/batch: 38.32s
# [Batch 667/800] Elapsed: 426.0 min | ETA: 84.9 min | Avg. time/batch: 38.32s
# [Batch 668/800] Elapsed: 426.7 min | ETA: 84.3 min | Avg. time/batch: 38.32s
# [Batch 669/800] Elapsed: 427.3 min | ETA: 83.7 min | Avg. time/batch: 38.33s
# [Batch 670/800] Elapsed: 428.0 min | ETA: 83.0 min | Avg. time/batch: 38.33s
# [Batch 671/800] Elapsed: 428.6 min | ETA: 82.4 min | Avg. time/batch: 38.33s
# [Batch 672/800] Elapsed: 429.2 min | ETA: 81.8 min | Avg. time/batch: 38.32s
# [Batch 673/800] Elapsed: 429.9 min | ETA: 81.1 min | Avg. time/batch: 38.32s
# [Batch 674/800] Elapsed: 430.5 min | ETA: 80.5 min | Avg. time/batch: 38.32s
# [Batch 675/800] Elapsed: 431.1 min | ETA: 79.8 min | Avg. time/batch: 38.32s
# [Batch 676/800] Elapsed: 431.8 min | ETA: 79.2 min | Avg. time/batch: 38.32s
# [Batch 677/800] Elapsed: 432.4 min | ETA: 78.6 min | Avg. time/batch: 38.32s
# [Batch 678/800] Elapsed: 433.1 min | ETA: 77.9 min | Avg. time/batch: 38.33s
# [Batch 679/800] Elapsed: 433.7 min | ETA: 77.3 min | Avg. time/batch: 38.33s
# [Batch 680/800] Elapsed: 434.4 min | ETA: 76.7 min | Avg. time/batch: 38.33s
# [Batch 681/800] Elapsed: 435.0 min | ETA: 76.0 min | Avg. time/batch: 38.33s
# [Batch 682/800] Elapsed: 435.7 min | ETA: 75.4 min | Avg. time/batch: 38.33s
# [Batch 683/800] Elapsed: 436.3 min | ETA: 74.7 min | Avg. time/batch: 38.33s
# [Batch 684/800] Elapsed: 437.0 min | ETA: 74.1 min | Avg. time/batch: 38.33s
# [Batch 685/800] Elapsed: 437.6 min | ETA: 73.5 min | Avg. time/batch: 38.33s
# [Batch 686/800] Elapsed: 438.2 min | ETA: 72.8 min | Avg. time/batch: 38.32s
# [Batch 687/800] Elapsed: 438.8 min | ETA: 72.2 min | Avg. time/batch: 38.33s
# [Batch 688/800] Elapsed: 439.5 min | ETA: 71.5 min | Avg. time/batch: 38.33s
# [Batch 689/800] Elapsed: 440.1 min | ETA: 70.9 min | Avg. time/batch: 38.32s
# [Batch 690/800] Elapsed: 440.7 min | ETA: 70.3 min | Avg. time/batch: 38.33s
# [Batch 691/800] Elapsed: 441.4 min | ETA: 69.6 min | Avg. time/batch: 38.33s
# [Batch 692/800] Elapsed: 442.1 min | ETA: 69.0 min | Avg. time/batch: 38.33s
# [Batch 693/800] Elapsed: 442.7 min | ETA: 68.4 min | Avg. time/batch: 38.33s
# [Batch 694/800] Elapsed: 443.4 min | ETA: 67.7 min | Avg. time/batch: 38.33s
# [Batch 695/800] Elapsed: 444.0 min | ETA: 67.1 min | Avg. time/batch: 38.33s
# [Batch 696/800] Elapsed: 444.6 min | ETA: 66.4 min | Avg. time/batch: 38.33s
# [Batch 697/800] Elapsed: 445.3 min | ETA: 65.8 min | Avg. time/batch: 38.33s
# [Batch 698/800] Elapsed: 445.9 min | ETA: 65.2 min | Avg. time/batch: 38.33s
# [Batch 699/800] Elapsed: 446.5 min | ETA: 64.5 min | Avg. time/batch: 38.33s
# [Batch 700/800] Elapsed: 447.2 min | ETA: 63.9 min | Avg. time/batch: 38.33s
# 💾 Saved checkpoint with 17500 rows to partial_simplified_notes.csv
# [Batch 701/800] Elapsed: 447.8 min | ETA: 63.2 min | Avg. time/batch: 38.33s
# [Batch 702/800] Elapsed: 448.5 min | ETA: 62.6 min | Avg. time/batch: 38.33s
# [Batch 703/800] Elapsed: 449.1 min | ETA: 62.0 min | Avg. time/batch: 38.33s
# [Batch 704/800] Elapsed: 449.7 min | ETA: 61.3 min | Avg. time/batch: 38.33s
# [Batch 705/800] Elapsed: 450.4 min | ETA: 60.7 min | Avg. time/batch: 38.33s
# [Batch 706/800] Elapsed: 451.1 min | ETA: 60.1 min | Avg. time/batch: 38.33s
# [Batch 707/800] Elapsed: 451.7 min | ETA: 59.4 min | Avg. time/batch: 38.33s
# [Batch 708/800] Elapsed: 452.4 min | ETA: 58.8 min | Avg. time/batch: 38.34s
# [Batch 709/800] Elapsed: 453.0 min | ETA: 58.1 min | Avg. time/batch: 38.33s
# [Batch 710/800] Elapsed: 453.5 min | ETA: 57.5 min | Avg. time/batch: 38.32s
# [Batch 711/800] Elapsed: 454.2 min | ETA: 56.8 min | Avg. time/batch: 38.33s
# [Batch 712/800] Elapsed: 454.7 min | ETA: 56.2 min | Avg. time/batch: 38.32s
# [Batch 713/800] Elapsed: 455.3 min | ETA: 55.6 min | Avg. time/batch: 38.31s
# [Batch 714/800] Elapsed: 455.9 min | ETA: 54.9 min | Avg. time/batch: 38.31s
# [Batch 715/800] Elapsed: 456.5 min | ETA: 54.3 min | Avg. time/batch: 38.31s
# [Batch 716/800] Elapsed: 457.1 min | ETA: 53.6 min | Avg. time/batch: 38.31s
# [Batch 717/800] Elapsed: 457.8 min | ETA: 53.0 min | Avg. time/batch: 38.31s
# [Batch 718/800] Elapsed: 458.4 min | ETA: 52.4 min | Avg. time/batch: 38.31s
# [Batch 719/800] Elapsed: 459.1 min | ETA: 51.7 min | Avg. time/batch: 38.31s
# [Batch 720/800] Elapsed: 459.7 min | ETA: 51.1 min | Avg. time/batch: 38.31s
# [Batch 721/800] Elapsed: 460.3 min | ETA: 50.4 min | Avg. time/batch: 38.31s
# [Batch 722/800] Elapsed: 461.0 min | ETA: 49.8 min | Avg. time/batch: 38.31s
# [Batch 723/800] Elapsed: 461.6 min | ETA: 49.2 min | Avg. time/batch: 38.31s
# [Batch 724/800] Elapsed: 462.3 min | ETA: 48.5 min | Avg. time/batch: 38.31s
# [Batch 725/800] Elapsed: 462.9 min | ETA: 47.9 min | Avg. time/batch: 38.31s
# [Batch 726/800] Elapsed: 463.6 min | ETA: 47.3 min | Avg. time/batch: 38.31s
# [Batch 727/800] Elapsed: 464.2 min | ETA: 46.6 min | Avg. time/batch: 38.31s
# [Batch 728/800] Elapsed: 464.8 min | ETA: 46.0 min | Avg. time/batch: 38.31s
# [Batch 729/800] Elapsed: 465.4 min | ETA: 45.3 min | Avg. time/batch: 38.31s
# [Batch 730/800] Elapsed: 466.0 min | ETA: 44.7 min | Avg. time/batch: 38.30s
# [Batch 731/800] Elapsed: 466.7 min | ETA: 44.1 min | Avg. time/batch: 38.30s
# [Batch 732/800] Elapsed: 467.3 min | ETA: 43.4 min | Avg. time/batch: 38.31s
# [Batch 733/800] Elapsed: 468.0 min | ETA: 42.8 min | Avg. time/batch: 38.31s
# [Batch 734/800] Elapsed: 468.6 min | ETA: 42.1 min | Avg. time/batch: 38.30s
# [Batch 735/800] Elapsed: 469.3 min | ETA: 41.5 min | Avg. time/batch: 38.31s
# [Batch 736/800] Elapsed: 469.9 min | ETA: 40.9 min | Avg. time/batch: 38.31s
# [Batch 737/800] Elapsed: 470.5 min | ETA: 40.2 min | Avg. time/batch: 38.31s
# [Batch 738/800] Elapsed: 471.2 min | ETA: 39.6 min | Avg. time/batch: 38.31s
# [Batch 739/800] Elapsed: 471.8 min | ETA: 38.9 min | Avg. time/batch: 38.30s
# [Batch 740/800] Elapsed: 472.4 min | ETA: 38.3 min | Avg. time/batch: 38.30s
# [Batch 741/800] Elapsed: 473.1 min | ETA: 37.7 min | Avg. time/batch: 38.30s
# [Batch 742/800] Elapsed: 473.7 min | ETA: 37.0 min | Avg. time/batch: 38.31s
# [Batch 743/800] Elapsed: 474.3 min | ETA: 36.4 min | Avg. time/batch: 38.30s
# [Batch 744/800] Elapsed: 475.0 min | ETA: 35.8 min | Avg. time/batch: 38.30s
# [Batch 745/800] Elapsed: 475.6 min | ETA: 35.1 min | Avg. time/batch: 38.31s
# [Batch 746/800] Elapsed: 476.3 min | ETA: 34.5 min | Avg. time/batch: 38.31s
# [Batch 747/800] Elapsed: 476.9 min | ETA: 33.8 min | Avg. time/batch: 38.31s
# [Batch 748/800] Elapsed: 477.6 min | ETA: 33.2 min | Avg. time/batch: 38.31s
# [Batch 749/800] Elapsed: 478.3 min | ETA: 32.6 min | Avg. time/batch: 38.31s
# [Batch 750/800] Elapsed: 479.0 min | ETA: 31.9 min | Avg. time/batch: 38.32s
# [Batch 751/800] Elapsed: 479.7 min | ETA: 31.3 min | Avg. time/batch: 38.32s
# [Batch 752/800] Elapsed: 480.4 min | ETA: 30.7 min | Avg. time/batch: 38.33s
# [Batch 753/800] Elapsed: 481.0 min | ETA: 30.0 min | Avg. time/batch: 38.33s
# [Batch 754/800] Elapsed: 481.7 min | ETA: 29.4 min | Avg. time/batch: 38.33s
# [Batch 755/800] Elapsed: 482.4 min | ETA: 28.7 min | Avg. time/batch: 38.33s
# [Batch 756/800] Elapsed: 483.0 min | ETA: 28.1 min | Avg. time/batch: 38.33s
# [Batch 757/800] Elapsed: 483.7 min | ETA: 27.5 min | Avg. time/batch: 38.34s
# [Batch 758/800] Elapsed: 484.4 min | ETA: 26.8 min | Avg. time/batch: 38.34s
# [Batch 759/800] Elapsed: 485.0 min | ETA: 26.2 min | Avg. time/batch: 38.34s
# [Batch 760/800] Elapsed: 485.7 min | ETA: 25.6 min | Avg. time/batch: 38.34s
# [Batch 761/800] Elapsed: 486.4 min | ETA: 24.9 min | Avg. time/batch: 38.35s
# [Batch 762/800] Elapsed: 487.0 min | ETA: 24.3 min | Avg. time/batch: 38.35s
# [Batch 763/800] Elapsed: 487.7 min | ETA: 23.7 min | Avg. time/batch: 38.35s
# [Batch 764/800] Elapsed: 488.4 min | ETA: 23.0 min | Avg. time/batch: 38.36s
# [Batch 765/800] Elapsed: 489.1 min | ETA: 22.4 min | Avg. time/batch: 38.36s
# [Batch 766/800] Elapsed: 489.8 min | ETA: 21.7 min | Avg. time/batch: 38.36s
# [Batch 767/800] Elapsed: 490.4 min | ETA: 21.1 min | Avg. time/batch: 38.36s
# [Batch 768/800] Elapsed: 491.1 min | ETA: 20.5 min | Avg. time/batch: 38.37s
# [Batch 769/800] Elapsed: 491.8 min | ETA: 19.8 min | Avg. time/batch: 38.37s
# [Batch 770/800] Elapsed: 492.4 min | ETA: 19.2 min | Avg. time/batch: 38.37s
# [Batch 771/800] Elapsed: 493.1 min | ETA: 18.5 min | Avg. time/batch: 38.37s
# [Batch 772/800] Elapsed: 493.7 min | ETA: 17.9 min | Avg. time/batch: 38.37s
# [Batch 773/800] Elapsed: 494.4 min | ETA: 17.3 min | Avg. time/batch: 38.38s
# [Batch 774/800] Elapsed: 495.1 min | ETA: 16.6 min | Avg. time/batch: 38.38s
# [Batch 775/800] Elapsed: 495.8 min | ETA: 16.0 min | Avg. time/batch: 38.38s
# [Batch 776/800] Elapsed: 496.4 min | ETA: 15.4 min | Avg. time/batch: 38.38s
# [Batch 777/800] Elapsed: 497.1 min | ETA: 14.7 min | Avg. time/batch: 38.39s
# [Batch 778/800] Elapsed: 497.8 min | ETA: 14.1 min | Avg. time/batch: 38.39s
# [Batch 779/800] Elapsed: 498.5 min | ETA: 13.4 min | Avg. time/batch: 38.39s
# [Batch 780/800] Elapsed: 499.1 min | ETA: 12.8 min | Avg. time/batch: 38.39s
# [Batch 781/800] Elapsed: 499.7 min | ETA: 12.2 min | Avg. time/batch: 38.39s
# [Batch 782/800] Elapsed: 500.4 min | ETA: 11.5 min | Avg. time/batch: 38.39s
# [Batch 783/800] Elapsed: 501.0 min | ETA: 10.9 min | Avg. time/batch: 38.39s
# [Batch 784/800] Elapsed: 501.7 min | ETA: 10.2 min | Avg. time/batch: 38.39s
# [Batch 785/800] Elapsed: 502.4 min | ETA: 9.6 min | Avg. time/batch: 38.40s
# [Batch 786/800] Elapsed: 503.0 min | ETA: 9.0 min | Avg. time/batch: 38.40s
# [Batch 787/800] Elapsed: 503.7 min | ETA: 8.3 min | Avg. time/batch: 38.40s
# [Batch 788/800] Elapsed: 504.3 min | ETA: 7.7 min | Avg. time/batch: 38.40s
# [Batch 789/800] Elapsed: 505.0 min | ETA: 7.0 min | Avg. time/batch: 38.40s
# [Batch 790/800] Elapsed: 505.6 min | ETA: 6.4 min | Avg. time/batch: 38.40s
# [Batch 791/800] Elapsed: 506.3 min | ETA: 5.8 min | Avg. time/batch: 38.40s
# [Batch 792/800] Elapsed: 507.0 min | ETA: 5.1 min | Avg. time/batch: 38.41s
# [Batch 793/800] Elapsed: 507.6 min | ETA: 4.5 min | Avg. time/batch: 38.41s
# [Batch 794/800] Elapsed: 508.3 min | ETA: 3.8 min | Avg. time/batch: 38.41s
# [Batch 795/800] Elapsed: 509.1 min | ETA: 3.2 min | Avg. time/batch: 38.42s
# [Batch 796/800] Elapsed: 509.8 min | ETA: 2.6 min | Avg. time/batch: 38.42s
# [Batch 797/800] Elapsed: 510.5 min | ETA: 1.9 min | Avg. time/batch: 38.43s
# [Batch 798/800] Elapsed: 511.2 min | ETA: 1.3 min | Avg. time/batch: 38.43s
# [Batch 799/800] Elapsed: 511.9 min | ETA: 0.6 min | Avg. time/batch: 38.44s
# [Batch 800/800] Elapsed: 512.6 min | ETA: 0.0 min | Avg. time/batch: 38.44s
# 💾 Saved checkpoint with 20000 rows to partial_simplified_notes.csv

# %%
# -------------------------------------
# 6. Final Save
# -------------------------------------
print("\n✅ Inference complete. Saving final results...")
df['Simplified_Note'] = pd.Series(outputs)
df.to_csv(FINAL_CSV, index=False)
print(f"✅ Saved {len(outputs)} final results to {FINAL_CSV}")
# Out:
# ✅ Inference complete. Saving final results...
# ✅ Saved 20000 final results to final_simplified_notes.csv
